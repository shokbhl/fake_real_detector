# %%
# Import required modules
import requests
from bs4 import BeautifulSoup
from transformers import pipeline

# Install necessary libraries
# !pip install transformers

# Import required modules
import requests
from bs4 import BeautifulSoup
from transformers import pipeline

# Define the RoBERTa-based question-answering pipeline
qa_pipeline = pipeline("question-answering", model="deepset/roberta-base-squad2", tokenizer="deepset/roberta-base-squad2")

# Continue with the rest of your code...


# Import required modules
import requests
from bs4 import BeautifulSoup
from transformers import pipeline

# Function to get BBC News topics
def get_bbc_news_topics():
    url = 'https://www.bbc.com/news'
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        topics = []

        # Find topics under the 'News' section
        news_section = soup.find('a', {'href': '/news'})
        if news_section:
            topic_list = news_section.find_next('ul')
            if topic_list:
                topics = [(index + 1, topic.text, topic['href']) for index, topic in enumerate(topic_list.find_all('a'))]

        return topics
    else:
        print(f"Error: Unable to fetch topics. Status code: {response.status_code}")
        return []

# Function to scrape data with specified classes
# Function to scrape data with specified classes or XPath expression
def scrape_with_classes_or_xpath(soup, classes_or_xpath):
    scraped_data = {}

    for item in classes_or_xpath:
        elements = soup.select(item) if "contains" not in item else soup.find_all(True, class_=item)
        if elements:
            scraped_data[item] = [element.get_text(strip=True) for element in elements]

    return scraped_data

# ...

# Specify your complex XPath expression
complex_xpath_expression = """
    /*[contains(concat( " ", @class, " " ), concat( " ", "gbfmnQ", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "jqwZKz", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "kTrQIN", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "dJMMNx", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "fXIgdM", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "crzIlm", " "))]

    //*[contains(concat( " ", @class, " " ), concat( " ", "e1lr2am05", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "exn3ah91", " "))]

    //*[contains(concat( " ", @class, " " ), concat( " ", "gclMev", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "dEAAFJ", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "gbfmnQ", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "crzIlm", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "jjGBqh", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "jSYXeA", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "dQLcvL", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "dDrEZj", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "jqwZKz", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "kTrQIN", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "kbvxap", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "eRlFvc", " "))]

    //*[contains(concat( " ", @class, " " ), concat( " ", "gclMev", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "dEAAFJ", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "jjGBqh", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "jSYXeA", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "czRLo", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "jqwZKz", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "kTrQIN", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "dJMMNx", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "crzIlm", " " ))]

    //*[contains(concat( " ", @class, " " ), concat( " ", "gclMev", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "dEAAFJ", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "jjGBqh", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "jSYXeA", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "gbfmnQ", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "crzIlm", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "hgjZnQ", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "cMUkKA", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "jqwZKz", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "kTrQIN", " " ))]

    //*[contains(concat( " ", @class, " " ), concat( " ", "gclMev", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "dEAAFJ", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "jjGBqh", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "jSYXeA", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "jqwZKz", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "kTrQIN", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "rvuBc", " " ))] |
        //*[contains(concat( " ", @class, " " ), concat( " ", "hsVTfF", " " )))]

    //*[contains(concat( " ", @class, " " ), concat( " ", "gclMev", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "dEAAFJ", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "jjGBqh", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "jSYXeA", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "gbfmnQ", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "crzIlm", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "jqwZKz", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "hgjZnQ", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "cMUkKA", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "kTrQIN", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "decnVo", " " ))]

    //*[contains(concat( " ", @class, " " ), concat( " ", "gclMev", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "dEAAFJ", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "tNXLm", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "gBHnNH", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "jjGBqh", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "jSYXeA", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "hOBho", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "DOrVl", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "iqoFjT", " " ))]

    //*[contains(concat( " ", @class, " " ), concat( " ", "mJgTp", " " ))] |
    //*[contains(concat( " ", @class, " " ), concat( " ", "eUBbBH", " "))]"""

# Use RoBERTa for question answering on the user's question and scraped data
for item in complex_xpath_expression.split('|'):
    elements = soup.select(item.strip()) if "contains" not in item else soup.find_all(True, class_=item.strip())
    if elements:
        scraped_data[item.strip()] = [element.get_text(strip=True) for element in elements]

# Print scraped data for verification
for class_name, data_list in scraped_data.items():
    print(f"Class: {class_name}")
    for data in data_list:
        print(f"Data: {data}")
    print()



# Function to generate responses using the RoBERTa model for question answering
def generate_response_roberta(question, context):
    answer = qa_pipeline(question=question, context=context)
    return answer['answer']

# Scrape BBC news topics
topics = get_bbc_news_topics()

if not topics:
    print("No topics found. Exiting.")
else:
    # Display available topics to the user
    print("Available topics:")
    for topic in topics:
        print(f"{topic[0]}. {topic[1]} - URL: https://www.bbc.com{topic[2]}")

    # Ask the user to choose a topic
    try:
        user_choice = input("Enter the number corresponding to the desired topic: ")
        selected_topic = topics[int(user_choice) - 1]

        print(f"You selected: {selected_topic[1]} - URL: https://www.bbc.com{selected_topic[2]}")
        topic_url = f'https://www.bbc.com{selected_topic[2]}'

        # Make a request for the topic page
        topic_response = requests.get(topic_url)

        if topic_response.status_code == 200:
            soup = BeautifulSoup(topic_response.text, 'html.parser')

            # Classes to check
            classes_to_check = ["gclMev", "dEAAFJ", "czRLo", "jqwZKz", "kTrQIN", "dJMMNx", "crzIlm"]

            # Scrape elements with specified classes
            scraped_data = scrape_with_classes(soup, classes_to_check)

            # Ask the user to enter a question for RoBERTa-based question answering
            user_question = input("Enter a question about the selected topic: ")

            # Use RoBERTa for question answering on the user's question and scraped data
            for class_name, data_list in scraped_data.items():
                for data in data_list:
                    question = f"What is {data} about?"
                    answer = generate_response_roberta(question, user_question)
                    print(f"Question: {question}")
                    print(f"Answer: {answer}")
                    print()

        else:
            print(f"Error: Unable to fetch topic page. Status code: {topic_response.status_code}")

    except (ValueError, IndexError):
        print("Invalid choice. Please enter a valid topic number.")


# ...

# Function to check if the news is real by verifying against BBC Reality Check page
def check_reality(news_title):
    reality_check_url = 'https://www.bbc.com/news/reality_check'
    reality_check_response = requests.get(reality_check_url)

    if reality_check_response.status_code == 200:
        reality_check_soup = BeautifulSoup(reality_check_response.text, 'html.parser')
        reality_check_articles = reality_check_soup.find_all('article', class_='gs-c-promo')

        for article in reality_check_articles:
            article_title = article.find('h3', class_='gs-c-promo-heading__title')
            article_paragraphs = article.find_all('p', class_='gs-c-promo-summary')

            if article_title and article_paragraphs:
                title_text = article_title.get_text().lower()
                paragraphs_text = [p.get_text().lower() for p in article_paragraphs]

                if all(keyword.lower() in title_text or keyword.lower() in paragraphs_text for keyword in news_title.split()):
                    # News found on the Reality Check page, considered real
                    article_link = article.find('a', class_='gs-c-promo-heading')['href']
                    full_link = f"https://www.bbc.com{article_link}"
                    return full_link

        return None  # News not found on the Reality Check page
    else:
        print(f"Error: Unable to fetch Reality Check page. Status code: {reality_check_response.status_code}")
        return None

# ...

# Use RoBERTa for question answering on the user's question and scraped data
for class_name, data_list in scraped_data.items():
    for data in data_list:
        question = f"What is {data} about?"
        answer = generate_response_roberta(question, user_question)
        print(f"Question: {question}")
        print(f"Answer: {answer}")

        # Check if the news is real and get the link if it is
        news_title = f"{data} {answer}"
        real_news_link = check_reality(news_title)

        if real_news_link:
            print(f"This news is considered real. Related link: {real_news_link}")
        else:
            print("This news may be fake or is not on the Reality Check page.")

        print()
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.37.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Available topics:
# 1. Israel-Gaza War - URL: https://www.bbc.com/news/topics/c2vdnvdg6xxt
# 2. War in Ukraine - URL: https://www.bbc.com/news/war-in-ukraine
# 3. World - URL: https://www.bbc.com/news/world
# 4. US & Canada - URL: https://www.bbc.com/news/us-canada
# 5. UK - URL: https://www.bbc.com/news/uk
# 6. In Pictures - URL: https://www.bbc.com/news/in_pictures
# 7. BBC Verify - URL: https://www.bbc.com/news/reality_check
# Enter the number corresponding to the desired topic: 1
# You selected: Israel-Gaza War - URL: https://www.bbc.com/news/topics/c2vdnvdg6xxt
# Enter a question about the selected topic: green light to continued slaughter
# Question: What is Rishi Sunak says the “usual ways in which Parliament works were changed” in the Speaker’s handling of an Opposition Day debate and vote. about?
# Answer: green light to continued slaughter
#
# Question: What is The BBC's Quentin Sommerville joins flights dropping aid into Gaza and flying out civilians. about?
# Answer: green light to continued slaughter
#
# Question: What is There was no immediate claim from Yemen's Houthi rebels, who are targeting vessels in the region. about?
# Answer: green light to continued slaughter
#
# Question: What is Thirteen other people were hurt when three attackers shot at vehicles in a traffic jam, police say. about?
# Answer: green light to continued slaughter
#
# Question: What is SNP Westminster leader Stephen Flynn says the Speaker has lost his party's confidence and can not carry on. about?
# Answer: green light to continued slaughter
#
# Question: What is Stephen Flynn says Lindsay Hoyle “alone” is responsible for the “farce” in the Commons over calls for a Middle East ceasefire. about?
# Answer: green light to continued slaughter
#
# Question: What is The Labour leader says he “simply urged” the Speaker to ensure there was the “broadest possible debate” over calls for a Middle East ceasefire. about?
# Answer: green light to continued slaughter
#
# Question: What is People in the House of Commons Speaker's Chorley constituency have their say on row engulfing MP. about?
# Answer: green light to continued slaughter
#
# Question: What is Concerns that Labour MPs would face protests informed his decision to table the party's vote. about?
# Answer: green light to continued slaughter
#
# Question: What is Sunak brands Hoyle decision 'concerning' about?
# Answer: green light to continued slaughter
#
# Question: What is On board the plane evacuating injured Palestinians about?
# Answer: slaughter
#
# Question: What is Ship damaged after missile attack in Gulf of Aden about?
# Answer: slaughter
#
# Question: What is Palestinian gunmen kill Israeli man in West Bank about?
# Answer: green light
#
# Question: What is How the row over Commons Speaker unfolded about?
# Answer: slaughter
#
# Question: What is SNP: We do not have confidence in Hoyle as Speaker about?
# Answer: green light to continued slaughter
#
# Question: What is Starmer: I did not threaten the Speaker in any way about?
# Answer: green light to continued slaughter
#
# Question: What is Speaker's constituents react to Gaza vote row about?
# Answer: slaughter
#
# Question: What is Speaker feared for MPs' safety before Gaza vote about?
# Answer: slaughter
#
# Question: What is Former spy chief tells BBC that Benjamin Netanyahu didn't act on advice to hit the group's money streams. about?
# Answer: green light to continued slaughter
#
# Question: What is UN doctors were granted access to the Nasser Medical Complex. One described it as a "death zone". about?
# Answer: green light to continued slaughter
#
# Question: What is The BBC's Quentin Sommerville was on board the Jordanian plane tasked with delivering the aid. about?
# Answer: green light to continued slaughter
#
# Question: What is Israel's government is under pressure to let people return to communities in the north and south. about?
# Answer: green light to continued slaughter
#
# Question: What is The BBC's Quentin Sommerville was on board the Jordanian plane tasked with delivering the aid. about?
# Answer: green light to continued slaughter
#
# Question: What is The Association of Rape Crisis Centers in Israel found "identical patterns" at 7 October attack sites. about?
# Answer: green light to continued slaughter
#
# Question: What is Beijing suggests blocking calls for an immediate ceasefire gives a “green light to continued slaughter". about?
# Answer: green light to continued slaughter
#
# Question: What is Large explosions can be seen in footage released by France from its patrol zones in the Red Sea. about?
# Answer: green light to continued slaughter
#
# Question: What is Israel's government is under pressure to let people return to communities in the north and south. about?
# Answer: green light to continued slaughter
#
# Question: What is Why did Hamas attack Israel, and what has happened in Gaza since the 7 October raid? about?
# Answer: continued slaughter
#
# Question: What is Find out how much has changed in the Gaza Strip since Israel began its military response to Hamas's attacks on 7 October. about?
# Answer: green light to continued slaughter
#
# Question: What is The Houthis in Yemen have vowed to attack all ships in the Red Sea that are linked to Israel. about?
# Answer: green light to continued slaughter
#
# Question: What is Supply chains face disruption due to vessels diverting away from the key shipping route. about?
# Answer: green light to continued slaughter
#
# Question: What is Tensions between Israel and the Palestinians date back decades, but what are the key issues? about?
# Answer: green light to continued slaughter
#
# Question: What is Reports claim the work could be in preparation for Palestinian refugees - something Egypt publicly denies. about?
# Answer: green light to continued slaughter
#
# Question: What is BBC Verify analyses footage from the Nasser hospital in southern Gaza as Israeli forces raid the complex. about?
# Answer: green light to continued slaughter
#
# Question: What is BBC Verify has analysed the latest satellite image from the city in southern Gaza. about?
# Answer: green light to continued slaughter
#
# Question: What is Jeremy Bowen looks at Gaza's humanitarian crisis and a growing panic in Rafah over a looming Israeli offensive. about?
# Answer: green light to continued slaughter
#
# Question: What is BBC's Paul Adams asks whether US strikes on Iraq and Syria made a regional conflagration more likely. about?
# Answer: green light to continued slaughter
#
# Question: What is BBC News Arabic followed three first responders working under intense bombardment in the first month of the war. about?
# Answer: green light to continued slaughter
#
# Question: What is The Israeli prime minister's popularity has declined among Israelis after the 7 October Hamas attacks. about?
# Answer: green light to continued slaughter
#
# Question: What is It is thought more than 100 Israelis are still being held hostage in Gaza after the 7 October attacks. about?
# Answer: green light to continued slaughter
#
# Question: What is Some 19,000 children have been orphaned by the war, or have no adults to look after them, says the UN. about?
# Answer: green light to continued slaughter
#
# Question: What is Eli Albag is haunted by the ordeal of his daughter Liri, held hostage in Gaza, as he campaigns for more pressure on Qatar. about?
# Answer: green light to continued slaughter
#
# Question: What is UK aid supplies air-dropped into Gaza for first time about?
# Answer: green light to continued slaughter
#
# Question: What is 'Evacuating was a mistake': Israelis push to return to border homes about?
# Answer: green light to continued slaughter
#
# Question: What is Israeli PM 'missed chance' to cut off Hamas cash about?
# Answer: green light to continued slaughter
#
# Question: What is WHO releases video from inside raided Gaza hospital about?
# Answer: slaughter
#
# Question: What is UK aid supplies air-dropped into Gaza for first time about?
# Answer: green light to continued slaughter
#
# Question: What is Israeli report says Hamas sexual crimes 'systematic' about?
# Answer: green light to continued slaughter
#
# Question: What is US veto sends wrong message over Gaza, says China about?
# Answer: green light to continued slaughter
#
# Question: What is French warships intercept drones from Yemen about?
# Answer: slaughter
#
# Question: What is 'Evacuating was a mistake': Israelis push to return to border homes about?
# Answer: green light to continued slaughter
#
# Question: What is Why are Israel and Hamas fighting in Gaza? about?
# Answer: green light to continued slaughter
#
# Question: What is Gaza Strip in maps: How life has changed in four months about?
# Answer: green light to continued slaughter
#
# Question: What is Who are the Houthis attacking Red Sea ships? about?
# Answer: slaughter
#
# Question: What is What do Red Sea assaults mean for global trade? about?
# Answer: green light to continued slaughter
#
# Question: What is Israel Gaza war: What are the key issues? about?
# Answer: green light to continued slaughter
#
# Question: What is Satellite images show construction on Egypt-Gaza border about?
# Answer: slaughter
#
# Question: What is What we can see in video from Nasser hospital raid about?
# Answer: green light to continued slaughter
#
# Question: What is Rafah images show huge blast craters close to camps about?
# Answer: slaughter
#
# Question: What is Israel-Gaza war: Death and Israel’s search for ‘total victory’ about?
# Answer: slaughter
#
# Question: What is What are routes out of this 'dangerous moment' in Middle East? about?
# Answer: green light to continued slaughter
#
# Question: What is Exclusive video: Trauma at every turn for Gaza’s exhausted paramedics about?
# Answer: green light to continued slaughter
#
# Question: What is Tel Aviv protesters call on Netanyahu to resign about?
# Answer: slaughter
#
# Question: What is Stories of the hostages taken by Hamas from Israel about?
about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is BBC's Paul Adams asks whether US strikes on Iraq and Syria made a regional conflagration more likely. about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is BBC News Arabic followed three first responders working under intense bombardment in the first month of the war. about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is The Israeli prime minister's popularity has declined among Israelis after the 7 October Hamas attacks. about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is It is thought more than 100 Israelis are still being held hostage in Gaza after the 7 October attacks. about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Some 19,000 children have been orphaned by the war, or have no adults to look after them, says the UN. about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Eli Albag is haunted by the ordeal of his daughter Liri, held hostage in Gaza, as he campaigns for more pressure on Qatar. about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is UK aid supplies air-dropped into Gaza for first time about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is 'Evacuating was a mistake': Israelis push to return to border homes about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Israeli PM 'missed chance' to cut off Hamas cash about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is WHO releases video from inside raided Gaza hospital about?
# Answer: slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is UK aid supplies air-dropped into Gaza for first time about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Israeli report says Hamas sexual crimes 'systematic' about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is US veto sends wrong message over Gaza, says China about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is French warships intercept drones from Yemen about?
# Answer: slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is 'Evacuating was a mistake': Israelis push to return to border homes about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Why are Israel and Hamas fighting in Gaza? about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Gaza Strip in maps: How life has changed in four months about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Who are the Houthis attacking Red Sea ships? about?
# Answer: slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is What do Red Sea assaults mean for global trade? about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Israel Gaza war: What are the key issues? about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Satellite images show construction on Egypt-Gaza border about?
# Answer: slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is What we can see in video from Nasser hospital raid about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Rafah images show huge blast craters close to camps about?
# Answer: slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Israel-Gaza war: Death and Israel’s search for ‘total victory’ about?
# Answer: slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is What are routes out of this 'dangerous moment' in Middle East? about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Exclusive video: Trauma at every turn for Gaza’s exhausted paramedics about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Tel Aviv protesters call on Netanyahu to resign about?
# Answer: slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Stories of the hostages taken by Hamas from Israel about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Injured, hungry and alone - the Gazan children orphaned by war about?
# Answer: slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is 'I go to sleep a dead man' - father's pain at daughter's captivity in Gaza about?
# Answer: slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Shrapnel ripped through the tents of displaced Palestinians as the Israeli military rescued two hostages. about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is People who survived the 7 October attacks in Israel by Hamas describe how events unfolded about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is 'Dad, please don't go out': The Gazans killed as Israel freed hostages about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is The Documentary Podcast: The Israeli hostages about?
# Answer: slaughter
# This news may be fake or is not on the Reality Check page.

# %%
# Import required modules
import requests
from bs4 import BeautifulSoup
from transformers import pipeline

# Install necessary libraries
#!pip install transformers

# Import required modules
import requests
from bs4 import BeautifulSoup
from transformers import pipeline

# Define the RoBERTa-based question-answering pipeline
qa_pipeline = pipeline("question-answering", model="deepset/roberta-base-squad2", tokenizer="deepset/roberta-base-squad2")

# Function to get BBC News topics
def get_bbc_news_topics():
    url = 'https://www.bbc.com/news'
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        topics = []

        # Find topics under the 'News' section
        news_section = soup.find('a', {'href': '/news'})
        if news_section:
            topic_list = news_section.find_next('ul')
            if topic_list:
                topics = [(index + 1, topic.text, topic['href']) for index, topic in enumerate(topic_list.find_all('a'))]

        return topics
    else:
        print(f"Error: Unable to fetch topics. Status code: {response.status_code}")
        return []

# Function to scrape data with specified classes or XPath expression
def scrape_with_classes_or_xpath(soup, classes_or_xpath):
    scraped_data = {}

    for item in classes_or_xpath:
        elements = soup.select(item) if "contains" not in item else soup.find_all(True, class_=item)
        if elements:
            scraped_data[item] = [element.get_text(strip=True) for element in elements]

    return scraped_data

# Function to generate responses using the RoBERTa model for question answering
def generate_response_roberta(question, context):
    answer = qa_pipeline(question=question, context=context)
    return answer['answer']

# Function to check if the news is real by verifying against BBC Reality Check page
def check_reality(news_title):
    reality_check_url = 'https://www.bbc.com/news/reality_check'
    reality_check_response = requests.get(reality_check_url)

    if reality_check_response.status_code == 200:
        reality_check_soup = BeautifulSoup(reality_check_response.text, 'html.parser')
        reality_check_articles = reality_check_soup.find_all('article', class_='gs-c-promo')

        for article in reality_check_articles:
            article_title = article.find('h3', class_='gs-c-promo-heading__title')
            article_paragraphs = article.find_all('p', class_='gs-c-promo-summary')

            if article_title and article_paragraphs:
                title_text = article_title.get_text().lower()
                paragraphs_text = [p.get_text().lower() for p in article_paragraphs]

                if all(keyword.lower() in title_text or keyword.lower() in paragraphs_text for keyword in news_title.split()):
                    # News found on the Reality Check page, considered real
                    article_link = article.find('a', class_='gs-c-promo-heading')['href']
                    full_link = f"https://www.bbc.com{article_link}"
                    return full_link

        return None  # News not found on the Reality Check page
    else:
        print(f"Error: Unable to fetch Reality Check page. Status code: {reality_check_response.status_code}")
        return None

# Continue with the rest of your code...
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.37.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)

# %%
# Function to check if the news is real by verifying against BBC Reality Check page
def check_reality(news_title):
    reality_check_url = 'https://www.bbc.com/news/reality_check'
    reality_check_response = requests.get(reality_check_url)

    if reality_check_response.status_code == 200:
        reality_check_soup = BeautifulSoup(reality_check_response.text, 'html.parser')
        reality_check_articles = reality_check_soup.find_all('article', class_='gs-c-promo')

        for article in reality_check_articles:
            article_title = article.find('h3', class_='gs-c-promo-heading__title')
            article_paragraphs = article.find_all('p', class_='gs-c-promo-summary')

            if article_title and article_paragraphs:
                title_text = article_title.get_text().lower()
                paragraphs_text = [p.get_text().lower() for p in article_paragraphs]

                if all(keyword.lower() in title_text or keyword.lower() in paragraphs_text for keyword in news_title.split()):
                    # News found on the Reality Check page, considered real
                    article_link = article.find('a', class_='gs-c-promo-heading')['href']
                    full_link = f"https://www.bbc.com{article_link}"
                    return full_link

        return None  # News not found on the Reality Check page
    else:
        print(f"Error: Unable to fetch Reality Check page. Status code: {reality_check_response.status_code}")
        return None

# ...

# Use RoBERTa for question answering on the user's question and scraped data
for class_name, data_list in scraped_data.items():
    for data in data_list:
        question = f"What is {data} about?"
        answer = generate_response_roberta(question, user_question)
        print(f"Question: {question}")
        print(f"Answer: {answer}")

        # Check if the news is real and get the link if it is
        news_title = f"{data} {answer}"
        real_news_link = check_reality(news_title)

        if real_news_link:
            print(f"This news is considered real. Related link: {real_news_link}")
        else:
            print("This news may be fake or is not on the Reality Check page.")

        print()
# Out:
# Question: What is Rishi Sunak says the “usual ways in which Parliament works were changed” in the Speaker’s handling of an Opposition Day debate and vote. about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is The BBC's Quentin Sommerville joins flights dropping aid into Gaza and flying out civilians. about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is There was no immediate claim from Yemen's Houthi rebels, who are targeting vessels in the region. about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Thirteen other people were hurt when three attackers shot at vehicles in a traffic jam, police say. about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is SNP Westminster leader Stephen Flynn says the Speaker has lost his party's confidence and can not carry on. about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Stephen Flynn says Lindsay Hoyle “alone” is responsible for the “farce” in the Commons over calls for a Middle East ceasefire. about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is The Labour leader says he “simply urged” the Speaker to ensure there was the “broadest possible debate” over calls for a Middle East ceasefire. about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is People in the House of Commons Speaker's Chorley constituency have their say on row engulfing MP. about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Concerns that Labour MPs would face protests informed his decision to table the party's vote. about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Sunak brands Hoyle decision 'concerning' about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is On board the plane evacuating injured Palestinians about?
# Answer: slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Ship damaged after missile attack in Gulf of Aden about?
# Answer: slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Palestinian gunmen kill Israeli man in West Bank about?
# Answer: green light
# This news may be fake or is not on the Reality Check page.
#
# Question: What is How the row over Commons Speaker unfolded about?
# Answer: slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is SNP: We do not have confidence in Hoyle as Speaker about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Starmer: I did not threaten the Speaker in any way about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Speaker's constituents react to Gaza vote row about?
# Answer: slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Speaker feared for MPs' safety before Gaza vote about?
# Answer: slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What is Former spy chief tells BBC that Benjamin Netanyahu didn't act on advice to hit the group's money streams. about?
# Answer: green light to continued slaughter
# This news may be fake or is not on the Reality Check page.
#
# Question: What