# %%
import requests
from bs4 import BeautifulSoup
import spacy

def get_available_topics():
    url = 'https://www.bbc.com/news'

    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        topics_list = soup.select('.sc-44f1f005-0 .hCrDEz')

        if topics_list:
            topics = {i + 1: topic.text.strip() for i, topic in enumerate(topics_list)}
            return topics
        else:
            print("No topics found on the page.")
            return {}
    else:
        print(f"Error: Unable to fetch topics. Status code: {response.status_code}")
        return {}

def get_articles(topic):
    url = f'https://www.bbc.com/news/{topic}'

    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        articles_list = soup.select('.sc-44f1f005-0 .hCrDEz')

        if articles_list:
            return [article.text.strip() for article in articles_list]
        else:
            print("No articles found on the page.")
            return []
    else:
        print(f"Error: Unable to fetch articles. Status code: {response.status_code}")
        return []

def compare_statements(input_statement, documents):
    if not documents:
        print(f"No documents found for comparison.")
        return False

    nlp = spacy.load('en_core_web_sm')
    input_doc = nlp(input_statement)

    for document in documents:
        document_doc = nlp(document)
        similarity = input_doc.similarity(document_doc)

        # Adjust the similarity threshold as needed
        if similarity > 0.8:
            return True

    return False

def main():
    data_source = input("Enter the data source ('twitter' or 'bbc_news'): ")

    if data_source.lower() == 'bbc_news':
        available_topics = get_available_topics()

        if not available_topics:
            print("No topics available. Exiting.")
            return

        print("Available topics:")
        for number, topic in available_topics.items():
            print(f"{number}. {topic}")

        topic_number = int(input("Enter the number corresponding to the desired topic: "))
        topic_identifier = available_topics.get(topic_number)

        if not topic_identifier:
            print("Invalid topic number. Exiting.")
            return

        input_statement = input("Enter the statement to verify: ")
        documents = get_articles(topic_identifier)
    else:
        print("Invalid data source. Supported sources: 'bbc_news'")
        return

    if documents:
        is_legitimate = compare_statements(input_statement, documents)

        if is_legitimate:
            print("The statement is legitimate based on the data source.")
        else:
            print("The statement is not found among documents.")
    else:
        print("No documents found for the topic.")

if __name__ == "__main__":
    main()
# Out:
# Enter the data source ('twitter' or 'bbc_news'): bbc_news
# Available topics:
# 1. Israel-Gaza War
# 2. War in Ukraine
# 3. World
# 4. US & Canada
# 5. UK
# 6. In Pictures
# 7. BBC Verify
# Enter the number corresponding to the desired topic: 3
# Enter the statement to verify: Protesters in Tel Aviv Tel Aviv protesters call on Netanyahu to resign The Israeli prime minister's popularity has declined among Israelis after the 7 October Hamas attacks.
# Error: Unable to fetch articles. Status code: 404
# No documents found for the topic.

# %%
import requests
from bs4 import BeautifulSoup

def get_bbc_news_topics():
    url = 'https://www.bbc.com/news'
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        topics = []

        # Find topics under the 'News' section
        news_section = soup.find('a', {'href': '/news'})
        if news_section:
            topic_list = news_section.find_next('ul')
            if topic_list:
                topics = [(index + 1, topic.text, topic['href']) for index, topic in enumerate(topic_list.find_all('a'))]

        return topics

    else:
        print(f"Error: Unable to fetch topics. Status code: {response.status_code}")
        return []

def choose_topic(topics):
    print("Available BBC News Topics:")
    for topic in topics:
        print(f"{topic[0]}. {topic[1]}")

    user_choice = input("Enter the number corresponding to the desired topic: ")
    return user_choice

def scrape_topic_page(topic_url):
    response = requests.get(topic_url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        # Add your scraping logic here
        print(f"Scraping data from {topic_url}")
        print("Scraped data:")
        #print(soup.prettify())
    else:
        print(f"Error: Unable to fetch topic page. Status code: {response.status_code}")

# Example usage:
bbc_topics = get_bbc_news_topics()

if bbc_topics:
    user_choice = choose_topic(bbc_topics)
    selected_topic = bbc_topics[int(user_choice) - 1]

    print(f"You selected: {selected_topic[1]}")
    scrape_topic_page(f'https://www.bbc.com{selected_topic[2]}')
else:
    print("No topics found.")
# Out:
# Available BBC News Topics:
# 1. Israel-Gaza War
# 2. War in Ukraine
# 3. World
# 4. US & Canada
# 5. UK
# 6. In Pictures
# 7. BBC Verify
# Enter the number corresponding to the desired topic: 3
# You selected: World
# Scraping data from https://www.bbc.com/news/world
# Scraped data:

# %%
import requests
from bs4 import BeautifulSoup

def get_bbc_news_topics():
    url = 'https://www.bbc.com/news'
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        topics = []

        # Find topics under the 'News' section
        news_section = soup.find('a', {'href': '/news'})
        if news_section:
            topic_list = news_section.find_next('ul')
            if topic_list:
                topics = [(index + 1, topic.text, topic['href']) for index, topic in enumerate(topic_list.find_all('a'))]

        return topics

    else:
        print(f"Error: Unable to fetch topics. Status code: {response.status_code}")
        return []

def choose_topic(topics):
    print("Available BBC News Topics:")
    for topic in topics:
        print(f"{topic[0]}. {topic[1]}")

    user_choice = input("Enter the number corresponding to the desired topic: ")
    return user_choice

def get_user_statement():
    return input("Enter the statement you are looking for on the selected topic page: ")

def scrape_topic_page(topic_url, statement):
    response = requests.get(topic_url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        # Add your specific scraping logic here
        # For example, checking if the statement is present in the page
        statement_found = statement.lower() in soup.get_text().lower()

        print(f"Scraping data from {topic_url}")
        print(f"Statement '{statement}' {'found' if statement_found else 'not found'} on the page.")
    else:
        print(f"Error: Unable to fetch topic page. Status code: {response.status_code}")

# Example usage:
bbc_topics = get_bbc_news_topics()

if bbc_topics:
    user_choice = choose_topic(bbc_topics)
    selected_topic = bbc_topics[int(user_choice) - 1]

    print(f"You selected: {selected_topic[1]}")
    user_statement = get_user_statement()
    scrape_topic_page(f'https://www.bbc.com{selected_topic[2]}', user_statement)
else:
    print("No topics found.")
# Out:
# Available BBC News Topics:
# 1. Israel-Gaza War
# 2. War in Ukraine
# 3. World
# 4. US & Canada
# 5. UK
# 6. In Pictures
# 7. BBC Verify
# Enter the number corresponding to the desired topic: 3
# You selected: World
# Enter the statement you are looking for on the selected topic page: Protesters in Tel Aviv Tel Aviv protesters call on Netanyahu to resign The Israeli prime minister's popularity has declined among Israelis after the 7 October Hamas attacks.
# Scraping data from https://www.bbc.com/news/world
# Statement 'Protesters in Tel Aviv Tel Aviv protesters call on Netanyahu to resign The Israeli prime minister's popularity has declined among Israelis after the 7 October Hamas attacks. ' not found on the page.

# %%
import requests
from bs4 import BeautifulSoup

def choose_data(data_list):
    print("Available Options:")
    for data in data_list:
        print(f"{data[0]}. {data[1]}")

    while True:
        user_choice = input("Enter the number corresponding to the desired option: ")
        if user_choice.isdigit() and 1 <= int(user_choice) <= len(data_list):
            return user_choice
        else:
            print("Invalid input. Please enter a valid number.")
def get_bbc_news_topics():
    url = 'https://www.bbc.com/news'
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # List of classes and IDs to check
        classes_and_ids_to_check = ['iframe', '.czRLo', '.jqwZKz', '.kTrQIN', '.kbvxap', '.crzIlm', '.dJMMNx', '.hPAmAW', '.huflns']

        for class_or_id in classes_and_ids_to_check:
            target_elements = soup.select(class_or_id)

            if target_elements:
                for index, element in enumerate(target_elements):
                    print(f"Content inside element with class or ID '{class_or_id}' {index + 1}:")
                    print(element.get_text(strip=True))
            else:
                print(f"No elements with class or ID '{class_or_id}' found.")
    else:
        print(f"Error: Unable to fetch data page. Status code: {response.status_code}")

# Example usage:
bbc_topics = get_bbc_news_topics()

if bbc_topics:
    user_choice = choose_topic(bbc_topics)
    selected_topic = bbc_topics[int(user_choice) - 1]

    print(f"You selected: {selected_topic[1]}")
    data_list = scrape_topic_page(f'https://www.bbc.com{selected_topic[2]}')

    if data_list:
        user_data_choice = choose_data(data_list)
        selected_data = data_list[int(user_data_choice) - 1]

        print(f"You selected: {selected_data[1]}")
        scrape_data_page(f'https://www.bbc.com{selected_data[2]}')

else:
    print("No topics found.")

def choose_topic(topics):
    print("Available BBC News Topics:")
    for topic in topics:
        print(f"{topic[0]}. {topic[1]}")

    user_choice = input("Enter the number corresponding to the desired topic: ")
    return user_choice

def get_user_statement():
    return input("Enter the statement you are looking for on the selected topic page: ")

def scrape_topic_page(topic_url, statement):
    response = requests.get(topic_url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        layers = topic_url.split('/')[4:]  # Extract layers from the URL

        # Navigate through the layers
        current_layer = soup
        for layer in layers:
            current_layer = current_layer.find('a', {'href': f'/{layer}'})
            if not current_layer:
                print(f"Error: Unable to navigate to layer '{layer}' in the topic page.")
                return

        # Add your specific scraping logic here
        # For example, checking if the statement is present in the page
        statement_found = statement.lower() in current_layer.get_text().lower()

        print(f"Scraping data from {topic_url}")
        print(f"Statement '{statement}' {'found' if statement_found else 'not found'} on the page.")
    else:
        print(f"Error: Unable to fetch topic page. Status code: {response.status_code}")

# Example usage:
bbc_topics = get_bbc_news_topics()

if bbc_topics:
    user_choice = choose_topic(bbc_topics)
    selected_topic = bbc_topics[int(user_choice) - 1]

    print(f"You selected: {selected_topic[1]}")
    user_statement = get_user_statement()
    scrape_topic_page(f'https://www.bbc.com{selected_topic[2]}', user_statement)
else:
    print("No topics found.")
# Out:
# No elements with class or ID 'iframe' found.
# Content inside element with class or ID '.czRLo' 1:
# The American man lured two US women off a trail near Germany's famous Neuschwanstein Castle last year.
# Content inside element with class or ID '.czRLo' 2:
# Dramatic video shows the leak towering close to power lines blocking a road in College Station, Texas.
# Content inside element with class or ID '.czRLo' 3:
# The Kenyan and Nigerian presidents face domestic criticism for their frequent trips abroad.
# Content inside element with class or ID '.czRLo' 4:
# Kamal, from the occupied West Bank, had a well-paid job in Israel before the Hamas attacks - now he is in poverty.
# Content inside element with class or ID '.czRLo' 5:
# Australian three-time Olympic medallist Shane Rose is stood down from competition for wearing a mankini during a show jumping event.
# Content inside element with class or ID '.czRLo' 6:
# Laughter and tears for winners at the Bafta Awards 2024 in London.
# Content inside element with class or ID '.czRLo' 7:
# Red Bull will be the focus of attention when Formula 1 pre-season testing starts this week in Bahrain - for reasons both on and off the track.
# Content inside element with class or ID '.czRLo' 8:
# Three-time Olympic team eventing medallist Shane Rose is cleared to compete after a review into his mankini outfit at an event this month.
# Content inside element with class or ID '.jqwZKz' 1:
# Yulia Navalnaya kept a low profile in the past, but her husband's death could see her take a more public role.
# Content inside element with class or ID '.jqwZKz' 2:
# "I know the justice system will prevail," he says - but the lottery claims to have posted his numbers in error.
# Content inside element with class or ID '.jqwZKz' 3:
# Yulia Navalnaya kept a low profile in the past, but her husband's death could see her take a more public role.
# Content inside element with class or ID '.jqwZKz' 4:
# Inflation is down and "vibes" are up - but younger Americans especially remain sceptical after the pain of soaring prices.
# Content inside element with class or ID '.jqwZKz' 5:
# "I know the justice system will prevail," he says - but the lottery claims to have posted his numbers in error.
# Content inside element with class or ID '.jqwZKz' 6:
# Big names from films like Barbie, Oppenheimer and Saltburn step out at the British awards ceremony.
# Content inside element with class or ID '.jqwZKz' 7:
# Tala Abu Nahla and her family have finally made it to Cairo - now the work to rebuild their lives begins.
# Content inside element with class or ID '.jqwZKz' 8:
# Big names from films like Barbie, Oppenheimer and Saltburn step out at the British awards ceremony.
# Content inside element with class or ID '.jqwZKz' 9:
# The director of the 2022 Oscar-winning film speaks of his shock at the death of Alexei Navalny.
# Content inside element with class or ID '.jqwZKz' 10:
# The conflicts in Gaza and Ukraine underline deepening geopolitical tensions and economic uncertainties.
# Content inside element with class or ID '.jqwZKz' 11:
# Tala Abu Nahla and her family have finally made it to Cairo - now the work to rebuild their lives begins.
# Content inside element with class or ID '.jqwZKz' 12:
# Its gross domestic product contracted by far more than expected in the wake of the conflict with Gaza.
# Content inside element with class or ID '.jqwZKz' 13:
# Officials say 85% of all Bolivia's municipalities are now under alert due to heavy rains.
# Content inside element with class or ID '.jqwZKz' 14:
# Its gross domestic product contracted by far more than expected in the wake of the conflict with Gaza.
# Content inside element with class or ID '.jqwZKz' 15:
# The early release of Ridge Alkonis, who killed two in a car accident, stirs unease over US-Japan relations.
# Content inside element with class or ID '.jqwZKz' 16:
# Canada's wildfire season is not over, with dozens of winter fires still burning beneath the soil.
# Content inside element with class or ID '.jqwZKz' 17:
# Officials say 85% of all Bolivia's municipalities are now under alert due to heavy rains.
# Content inside element with class or ID '.jqwZKz' 18:
# Crystal Palace name former Eintracht Frankfurt boss Oliver Glasner their new manager, replacing Roy Hodgson who stepped down on Monday.
# Content inside element with class or ID '.jqwZKz' 19:
# Manchester United make an official approach to Newcastle for their sporting director Dan Ashworth.
# Content inside element with class or ID '.jqwZKz' 20:
# Crystal Palace name former Eintracht Frankfurt boss Oliver Glasner their new manager, replacing Roy Hodgson who stepped down on Monday.
# Content inside element with class or ID '.jqwZKz' 21:
# Roy Hodgson's nomadic 48-year career in management took him around the world but has surely ended at the place he called home - Crystal Palace.
# Content inside element with class or ID '.jqwZKz' 22:
# Coach Brendon McCullum says England are "hurting" after a 434-run defeat by India in the third Test, but have "no regrets".
# Content inside element with class or ID '.jqwZKz' 23:
# Manchester United make an official approach to Newcastle for their sporting director Dan Ashworth.
# Content inside element with class or ID '.kTrQIN' 1:
# Navalny's 'principled and fearless' widow
# Content inside element with class or ID '.kTrQIN' 2:
# US man sues lottery after being told $340m win is error
# Content inside element with class or ID '.kTrQIN' 3:
# Man admits to rape, murder of US tourist in Germany
# Content inside element with class or ID '.kTrQIN' 4:
# Huge water leak shoots into air on Texas street
# Content inside element with class or ID '.kTrQIN' 5:
# Navalny's 'principled and fearless' widow
# Content inside element with class or ID '.kTrQIN' 6:
# Voters feel better about the economy. Will it help Biden?
# Content inside element with class or ID '.kTrQIN' 7:
# US man sues lottery after being told $340m win is error
# Content inside element with class or ID '.kTrQIN' 8:
# Michael J Fox brings audience to tears at Baftas
# Content inside element with class or ID '.kTrQIN' 9:
# Assange's wife says he 'won't survive US extradition'
# Content inside element with class or ID '.kTrQIN' 10:
# Wife of killed police officer says 'he did what was right'
# Content inside element with class or ID '.kTrQIN' 11:
# Dozens shot dead in Papua New Guinea ambush
# Content inside element with class or ID '.kTrQIN' 12:
# Special forces stopped Afghan troops settling in UK
# Content inside element with class or ID '.kTrQIN' 13:
# Israeli PM 'missed chance' to cut off Hamas cash
# Content inside element with class or ID '.kTrQIN' 14:
# Renner returns to the stage at US awards ceremony
# Content inside element with class or ID '.kTrQIN' 15:
# Crew abandon cargo ship after attack off Yemen
# Content inside element with class or ID '.kTrQIN' 16:
# In pictures: Stars on the Baftas red carpet
# Content inside element with class or ID '.kTrQIN' 17:
# Relief and guilt after Gazans find safety in Egypt
# Content inside element with class or ID '.kTrQIN' 18:
# Africa's 'flying presidents' under fire for foreign trips
# Content inside element with class or ID '.kTrQIN' 19:
# 'I earned good money in Israel - now I can't even afford chocolate'
# Content inside element with class or ID '.kTrQIN' 20:
# In pictures: Stars on the Baftas red carpet
# Content inside element with class or ID '.kTrQIN' 21:
# The Oscar-winning film that captured Navalny's life and future death
# Content inside element with class or ID '.kTrQIN' 22:
# 'Lose-lose' anxiety marks global security talks in Munich
# Content inside element with class or ID '.kTrQIN' 23:
# Relief and guilt after Gazans find safety in Egypt
# Content inside element with class or ID '.kTrQIN' 24:
# Israel's economy shrinks sharply on Gaza war
# Content inside element with class or ID '.kTrQIN' 25:
# Alert as torrential rains hit Bolivia, killing dozens
# Content inside element with class or ID '.kTrQIN' 26:
# Australian show jumper under review for competing in mankini
# Content inside element with class or ID '.kTrQIN' 27:
# Watch Baftas 2024 best bits... in two minutes
# Content inside element with class or ID '.kTrQIN' 28:
# Israel's economy shrinks sharply on Gaza war
# Content inside element with class or ID '.kTrQIN' 29:
# A US sailor killed two near Tokyo - why is Japan asked to apologise?
# Content inside element with class or ID '.kTrQIN' 30:
# 'Zombie Fires' burning at an alarming rate in Canada
# Content inside element with class or ID '.kTrQIN' 31:
# Alert as torrential rains hit Bolivia, killing dozens
# Content inside element with class or ID '.kTrQIN' 32:
# Crystal Palace appoint Glasner as new manager
# Content inside element with class or ID '.kTrQIN' 33:
# Man Utd make Ashworth approach
# Content inside element with class or ID '.kTrQIN' 34:
# Red Bull the main focus as F1 testing starts
# Content inside element with class or ID '.kTrQIN' 35:
# Back on the horse - mankini rider cleared to return
# Content inside element with class or ID '.kTrQIN' 36:
# Crystal Palace appoint Glasner as new manager
# Content inside element with class or ID '.kTrQIN' 37:
# 'A season too far - time for Hodgson to hang up tracksuit'
# Content inside element with class or ID '.kTrQIN' 38:
# England 'hurting' after Rajkot defeat - McCullum
# Content inside element with class or ID '.kTrQIN' 39:
# Man Utd make Ashworth approach
# Content inside element with class or ID '.kbvxap' 1:
#
# Content inside element with class or ID '.kbvxap' 2:
#
# Content inside element with class or ID '.kbvxap' 3:
#
# Content inside element with class or ID '.kbvxap' 4:
#
# Content inside element with class or ID '.kbvxap' 5:
#
# Content inside element with class or ID '.kbvxap' 6:
#
# Content inside element with class or ID '.kbvxap' 7:
#
# Content inside element with class or ID '.kbvxap' 8:
#
# Content inside element with class or ID '.kbvxap' 9:
#
# Content inside element with class or ID '.kbvxap' 10:
#
# Content inside element with class or ID '.kbvxap' 11:
#
# Content inside element with class or ID '.kbvxap' 12:
#
# Content inside element with class or ID '.kbvxap' 13:
#
# Content inside element with class or ID '.kbvxap' 14:
#
# Content inside element with class or ID '.kbvxap' 15:
#
# Content inside element with class or ID '.kbvxap' 16:
#
# Content inside element with class or ID '.kbvxap' 17:
#
# Content inside element with class or ID '.kbvxap' 18:
#
# Content inside element with class or ID '.kbvxap' 19:
#
# Content inside element with class or ID '.kbvxap' 20:
#
# Content inside element with class or ID '.kbvxap' 21:
#
# Content inside element with class or ID '.kbvxap' 22:
#
# Content inside element with class or ID '.kbvxap' 23:
#
# Content inside element with class or ID '.kbvxap' 24:
#
# Content inside element with class or ID '.kbvxap' 25:
#
# Content inside element with class or ID '.kbvxap' 26:
#
# Content inside element with class or ID '.kbvxap' 27:
#
# Content inside element with class or ID '.crzIlm' 1:
# Navalny's grieving widow vows to continue his work
# Content inside element with class or ID '.crzIlm' 2:
# British birds photographed with rainbow wings
# Content inside element with class or ID '.crzIlm' 3:
# 'Oppenhomies' Murphy and Downey Jr rule Baftas
# Content inside element with class or ID '.crzIlm' 4:
# Premier League: Everton 1-1 Crystal Palace - Onana cancels out Ayew opener
# Content inside element with class or ID '.dJMMNx' 1:
# In a video message, Yulia Navalnaya also accused the Kremlin of being behind her husband's death in a Siberian jail.
# Content inside element with class or ID '.dJMMNx' 2:
# Wildlife photographer Andrew Fusek Peters has captured the "gobsmacking" images.
# Content inside element with class or ID '.dJMMNx' 3:
# Cillian Murphy, Robert Downey Jr and Christopher Nolan all win Bafta Film Awards for Oppenheimer.
# Content inside element with class or ID '.dJMMNx' 4:
# Follow live text updates as Everton play Crystal Palace in the Premier League.
# No elements with class or ID '.hPAmAW' found.
# No elements with class or ID '.huflns' found.
# No topics found.
# No elements with class or ID 'iframe' found.
# Content inside element with class or ID '.czRLo' 1:
# The American man lured two US women off a trail near Germany's famous Neuschwanstein Castle last year.
# Content inside element with class or ID '.czRLo' 2:
# Dramatic video shows the leak towering close to power lines blocking a road in College Station, Texas.
# Content inside element with class or ID '.czRLo' 3:
# The Kenyan and Nigerian presidents face domestic criticism for their frequent trips abroad.
# Content inside element with class or ID '.czRLo' 4:
# Kamal, from the occupied West Bank, had a well-paid job in Israel before the Hamas attacks - now he is in poverty.
# Content inside element with class or ID '.czRLo' 5:
# Australian three-time Olympic medallist Shane Rose is stood down from competition for wearing a mankini during a show jumping event.
# Content inside element with class or ID '.czRLo' 6:
# Laughter and tears for winners at the Bafta Awards 2024 in London.
# Content inside element with class or ID '.czRLo' 7:
# Red Bull will be the focus of attention when Formula 1 pre-season testing starts this week in Bahrain - for reasons both on and off the track.
# Content inside element with class or ID '.czRLo' 8:
# Three-time Olympic team eventing medallist Shane Rose is cleared to compete after a review into his mankini outfit at an event this month.
# Content inside element with class or ID '.jqwZKz' 1:
# Yulia Navalnaya kept a low profile in the past, but her husband's death could see her take a more public role.
# Content inside element with class or ID '.jqwZKz' 2:
# "I know the justice system will prevail," he says - but the lottery claims to have posted his numbers in error.
# Content inside element with class or ID '.jqwZKz' 3:
# Yulia Navalnaya kept a low profile in the past, but her husband's death could see her take a more public role.
# Content inside element with class or ID '.jqwZKz' 4:
# Inflation is down and "vibes" are up - but younger Americans especially remain sceptical after the pain of soaring prices.
# Content inside element with class or ID '.jqwZKz' 5:
# "I know the justice system will prevail," he says - but the lottery claims to have posted his numbers in error.
# Content inside element with class or ID '.jqwZKz' 6:
# Big names from films like Barbie, Oppenheimer and Saltburn step out at the British awards ceremony.
# Content inside element with class or ID '.jqwZKz' 7:
# Tala Abu Nahla and her family have finally made it to Cairo - now the work to rebuild their lives begins.
# Content inside element with class or ID '.jqwZKz' 8:
# Big names from films like Barbie, Oppenheimer and Saltburn step out at the British awards ceremony.
# Content inside element with class or ID '.jqwZKz' 9:
# The director of the 2022 Oscar-winning film speaks of his shock at the death of Alexei Navalny.
# Content inside element with class or ID '.jqwZKz' 10:
# The conflicts in Gaza and Ukraine underline deepening geopolitical tensions and economic uncertainties.
# Content inside element with class or ID '.jqwZKz' 11:
# Tala Abu Nahla and her family have finally made it to Cairo - now the work to rebuild their lives begins.
# Content inside element with class or ID '.jqwZKz' 12:
# Its gross domestic product contracted by far more than expected in the wake of the conflict with Gaza.
# Content inside element with class or ID '.jqwZKz' 13:
# Officials say 85% of all Bolivia's municipalities are now under alert due to heavy rains.
# Content inside element with class or ID '.jqwZKz' 14:
# Its gross domestic product contracted by far more than expected in the wake of the conflict with Gaza.
# Content inside element with class or ID '.jqwZKz' 15:
# The early release of Ridge Alkonis, who killed two in a car accident, stirs unease over US-Japan relations.
# Content inside element with class or ID '.jqwZKz' 16:
# Canada's wildfire season is not over, with dozens of winter fires still burning beneath the soil.
# Content inside element with class or ID '.jqwZKz' 17:
# Officials say 85% of all Bolivia's municipalities are now under alert due to heavy rains.
# Content inside element with class or ID '.jqwZKz' 18:
# Crystal Palace name former Eintracht Frankfurt boss Oliver Glasner their new manager, replacing Roy Hodgson who stepped down on Monday.
# Content inside element with class or ID '.jqwZKz' 19:
# Manchester United make an official approach to Newcastle for their sporting director Dan Ashworth.
# Content inside element with class or ID '.jqwZKz' 20:
# Crystal Palace name former Eintracht Frankfurt boss Oliver Glasner their new manager, replacing Roy Hodgson who stepped down on Monday.
# Content inside element with class or ID '.jqwZKz' 21:
# Roy Hodgson's nomadic 48-year career in management took him around the world but has surely ended at the place he called home - Crystal Palace.
# Content inside element with class or ID '.jqwZKz' 22:
# Coach Brendon McCullum says England are "hurting" after a 434-run defeat by India in the third Test, but have "no regrets".
# Content inside element with class or ID '.jqwZKz' 23:
# Manchester United make an official approach to Newcastle for their sporting director Dan Ashworth.
# Content inside element with class or ID '.kTrQIN' 1:
# Navalny's 'principled and fearless' widow
# Content inside element with class or ID '.kTrQIN' 2:
# US man sues lottery after being told $340m win is error
# Content inside element with class or ID '.kTrQIN' 3:
# Man admits to rape, murder of US tourist in Germany
# Content inside element with class or ID '.kTrQIN' 4:
# Huge water leak shoots into air on Texas street
# Content inside element with class or ID '.kTrQIN' 5:
# Navalny's 'principled and fearless' widow
# Content inside element with class or ID '.kTrQIN' 6:
# Voters feel better about the economy. Will it help Biden?
# Content inside element with class or ID '.kTrQIN' 7:
# US man sues lottery after being told $340m win is error
# Content inside element with class or ID '.kTrQIN' 8:
# Michael J Fox brings audience to tears at Baftas
# Content inside element with class or ID '.kTrQIN' 9:
# Assange's wife says he 'won't survive US extradition'
# Content inside element with class or ID '.kTrQIN' 10:
# Wife of killed police officer says 'he did what was right'
# Content inside element with class or ID '.kTrQIN' 11:
# Dozens shot dead in Papua New Guinea ambush
# Content inside element with class or ID '.kTrQIN' 12:
# Special forces stopped Afghan troops settling in UK
# Content inside element with class or ID '.kTrQIN' 13:
# Israeli PM 'missed chance' to cut off Hamas cash
# Content inside element with class or ID '.kTrQIN' 14:
# Renner returns to the stage at US awards ceremony
# Content inside element with class or ID '.kTrQIN' 15:
# Crew abandon cargo ship after attack off Yemen
# Content inside element with class or ID '.kTrQIN' 16:
# In pictures: Stars on the Baftas red carpet
# Content inside element with class or ID '.kTrQIN' 17:
# Relief and guilt after Gazans find safety in Egypt
# Content inside element with class or ID '.kTrQIN' 18:
# Africa's 'flying presidents' under fire for foreign trips
# Content inside element with class or ID '.kTrQIN' 19:
# 'I earned good money in Israel - now I can't even afford chocolate'
# Content inside element with class or ID '.kTrQIN' 20:
# In pictures: Stars on the Baftas red carpet
# Content inside element with class or ID '.kTrQIN' 21:
# The Oscar-winning film that captured Navalny's life and future death
# Content inside element with class or ID '.kTrQIN' 22:
# 'Lose-lose' anxiety marks global security talks in Munich
# Content inside element with class or ID '.kTrQIN' 23:
# Relief and guilt after Gazans find safety in Egypt
# Content inside element with class or ID '.kTrQIN' 24:
# Israel's economy shrinks sharply on Gaza war
# Content inside element with class or ID '.kTrQIN' 25:
# Alert as torrential rains hit Bolivia, killing dozens
# Content inside element with class or ID '.kTrQIN' 26:
# Australian show jumper under review for competing in mankini
# Content inside element with class or ID '.kTrQIN' 27:
# Watch Baftas 2024 best bits... in two minutes
# Content inside element with class or ID '.kTrQIN' 28:
# Israel's economy shrinks sharply on Gaza war
# Content inside element with class or ID '.kTrQIN' 29:
# A US sailor killed two near Tokyo - why is Japan asked to apologise?
# Content inside element with class or ID '.kTrQIN' 30:
# 'Zombie Fires' burning at an alarming rate in Canada
# Content inside element with class or ID '.kTrQIN' 31:
# Alert as torrential rains hit Bolivia, killing dozens
# Content inside element with class or ID '.kTrQIN' 32:
# Crystal Palace appoint Glasner as new manager
# Content inside element with class or ID '.kTrQIN' 33:
# Man Utd make Ashworth approach
# Content inside element with class or ID '.kTrQIN' 34:
# Red Bull the main focus as F1 testing starts
# Content inside element with class or ID '.kTrQIN' 35:
# Back on the horse - mankini rider cleared to return
# Content inside element with class or ID '.kTrQIN' 36:
# Crystal Palace appoint Glasner as new manager
# Content inside element with class or ID '.kTrQIN' 37:
# 'A season too far - time for Hodgson to hang up tracksuit'
# Content inside element with class or ID '.kTrQIN' 38:
# England 'hurting' after Rajkot defeat - McCullum
# Content inside element with class or ID '.kTrQIN' 39:
# Man Utd make Ashworth approach
# Content inside element with class or ID '.kbvxap' 1:
#
# Content inside element with class or ID '.kbvxap' 2:
#
# Content inside element with class or ID '.kbvxap' 3:
#
# Content inside element with class or ID '.kbvxap' 4:
#
# Content inside element with class or ID '.kbvxap' 5:
#
# Content inside element with class or ID '.kbvxap' 6:
#
# Content inside element with class or ID '.kbvxap' 7:
#
# Content inside element with class or ID '.kbvxap' 8:
#
# Content inside element with class or ID '.kbvxap' 9:
#
# Content inside element with class or ID '.kbvxap' 10:
#
# Content inside element with class or ID '.kbvxap' 11:
#
# Content inside element with class or ID '.kbvxap' 12:
#
# Content inside element with class or ID '.kbvxap' 13:
#
# Content inside element with class or ID '.kbvxap' 14:
#
# Content inside element with class or ID '.kbvxap' 15:
#
# Content inside element with class or ID '.kbvxap' 16:
#
# Content inside element with class or ID '.kbvxap' 17:
#
# Content inside element with class or ID '.kbvxap' 18:
#
# Content inside element with class or ID '.kbvxap' 19:
#
# Content inside element with class or ID '.kbvxap' 20:
#
# Content inside element with class or ID '.kbvxap' 21:
#
# Content inside element with class or ID '.kbvxap' 22:
#
# Content inside element with class or ID '.kbvxap' 23:
#
# Content inside element with class or ID '.kbvxap' 24:
#
# Content inside element with class or ID '.kbvxap' 25:
#
# Content inside element with class or ID '.kbvxap' 26:
#
# Content inside element with class or ID '.kbvxap' 27:
#
# Content inside element with class or ID '.crzIlm' 1:
# Navalny's grieving widow vows to continue his work
# Content inside element with class or ID '.crzIlm' 2:
# British birds photographed with rainbow wings
# Content inside element with class or ID '.crzIlm' 3:
# 'Oppenhomies' Murphy and Downey Jr rule Baftas
# Content inside element with class or ID '.crzIlm' 4:
# Premier League: Everton 1-1 Crystal Palace - Onana cancels out Ayew opener
# Content inside element with class or ID '.dJMMNx' 1:
# In a video message, Yulia Navalnaya also accused the Kremlin of being behind her husband's death in a Siberian jail.
# Content inside element with class or ID '.dJMMNx' 2:
# Wildlife photographer Andrew Fusek Peters has captured the "gobsmacking" images.
# Content inside element with class or ID '.dJMMNx' 3:
# Cillian Murphy, Robert Downey Jr and Christopher Nolan all win Bafta Film Awards for Oppenheimer.
# Content inside element with class or ID '.dJMMNx' 4:
# Follow live text updates as Everton play Crystal Palace in the Premier League.
# No elements with class or ID '.hPAmAW' found.
# No elements with class or ID '.huflns' found.
# No topics found.

# %%
import requests
from bs4 import BeautifulSoup

def get_bbc_news_topics():
    url = 'https://www.bbc.com/news'
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        topics = []

        # Find topics under the 'News' section
        news_section = soup.find('a', {'href': '/news'})
        if news_section:
            topic_list = news_section.find_next('ul')
            if topic_list:
                topics = [(index + 1, topic.text, topic['href']) for index, topic in enumerate(topic_list.find_all('a'))]

        return topics

    else:
        print(f"Error: Unable to fetch topics. Status code: {response.status_code}")
        return []

def scrape_with_classes(soup, classes):
    for class_name in classes:
        elements = soup.find_all(class_=class_name)
        if elements:
            print(f"Elements with class '{class_name}':")
            for element in elements:
                print(element.get_text(strip=True))
            print("\n")
        else:
            print(f"No elements with class '{class_name}' found.")

if __name__ == "__main__":
    # Get available topics
    topics = get_bbc_news_topics()

    if not topics:
        print("No topics found. Exiting.")
    else:
        # Display available topics to the user
        print("Available topics:")
        for topic in topics:
            print(f"{topic[0]}. {topic[1]} - URL: https://www.bbc.com{topic[2]}")

        # Ask the user to choose a topic
        try:
            user_choice = input("Enter the number corresponding to the desired topic: ")
            selected_topic = topics[int(user_choice) - 1]

            print(f"You selected: {selected_topic[1]} - URL: https://www.bbc.com{selected_topic[2]}")
            topic_url = f'https://www.bbc.com{selected_topic[2]}'

            # Make a request for the topic page
            topic_response = requests.get(topic_url)

            if topic_response.status_code == 200:
                soup = BeautifulSoup(topic_response.text, 'html.parser')

                # Classes to check
                classes_to_check = ["gclMev", "dEAAFJ", "czRLo", "jqwZKz", "kTrQIN", "dJMMNx", "crzIlm"]

                # Scrape elements with specified classes
                scrape_with_classes(soup, classes_to_check)

            else:
                print(f"Error: Unable to fetch topic page. Status code: {topic_response.status_code}")

        except (ValueError, IndexError):
            print("Invalid choice. Please enter a valid topic number.")
# Out:
# Available topics:
# 1. Israel-Gaza War - URL: https://www.bbc.com/news/topics/c2vdnvdg6xxt
# 2. War in Ukraine - URL: https://www.bbc.com/news/war-in-ukraine
# 3. World - URL: https://www.bbc.com/news/world
# 4. US & Canada - URL: https://www.bbc.com/news/us-canada
# 5. UK - URL: https://www.bbc.com/news/uk
# 6. In Pictures - URL: https://www.bbc.com/news/in_pictures
# 7. BBC Verify - URL: https://www.bbc.com/news/reality_check
# Enter the number corresponding to the desired topic: 3
# You selected: World - URL: https://www.bbc.com/news/world
# Elements with class 'gclMev':
# The American man lured two US women off a trail near Germany's famous Neuschwanstein Castle last year.
# Lawmakers are set to investigate claims the former government snooped on the phones of its opponents.
# The UK-registered Rubymar, which is carrying "very dangerous" fertiliser, has been taking on water.
# In a video message, Yulia Navalnaya also accused the Kremlin of being behind her husband's death in a Siberian jail.
# "I know the justice system will prevail," he says - but the lottery claims to have posted his numbers in error.
# An Irish government commitment  of £400m is set to be restored when the cabinet meets on Tuesday.
# A lengthy standoff at a family home leaves three first responders dead - as well as the gunman.
# A "nauseating" stench engulfing the South African city comes from a ship carrying 19,000 cows, officials say.
# Rescuers with shovels and axes are trying to find survivors in the country's eastern province.
#
#
# Elements with class 'dEAAFJ':
# Man admits to rape, murder of US tourist in Germany
# Poland spyware inquiry to quiz former ministers
# Crew abandon cargo ship after attack off Yemen
# Navalny's grieving widow vows to continue his work
# US man sues lottery after being told $340m win is error
# Irish government to restore cash promise for A5
# Wife of killed police officer says 'he did what was right'
# Cape Town stink blamed on cattle ship
# Landslide kills 25 after heavy snow in Afghanistan
#
#
# Elements with class 'czRLo':
# A "nauseating" stench engulfing the South African city comes from a ship carrying 19,000 cows, officials say.
# The country has long struggled with tribal violence, but the killings are believed to be the worst in years.
#
#
# Elements with class 'jqwZKz':
# Yulia Navalnaya kept a low profile in the past, but her husband's death could see her take a more public role.
# The UK-registered Rubymar, which is carrying "very dangerous" fertiliser, has been taking on water.
# Yulia Navalnaya kept a low profile in the past, but her husband's death could see her take a more public role.
# Indirect talks between Israel and Hamas have not brought the war to an end - and a pivotal few weeks looms.
# Former spy chief tells BBC that Benjamin Netanyahu didn't act on advice to hit the group's money streams.
# The UK-registered Rubymar, which is carrying "very dangerous" fertiliser, has been taking on water.
# Rescuers with shovels and axes are trying to find survivors in the country's eastern province.
# Officials say 85% of all Bolivia's municipalities are now under alert due to heavy rains.
# Lawmakers are set to investigate claims the former government snooped on the phones of its opponents.
# Israel's military says it hit weapons depots in response to a drone launched by Hezbollah.
# The conflicts in Gaza and Ukraine underline deepening geopolitical tensions and economic uncertainties.
# The Israeli prime minister's popularity has declined among Israelis after the 7 October Hamas attacks.
# Israel's PM Benjamin Netanyahu vows to carry on the war against Hamas regardless of international pressure.
# Doctors in Gaza say the healthcare system is broken and they are operating on people without anaesthetic.
# Further damage is reported at Nasser, as Israel says it has captured 7 October attackers there.
# BBC Verify has analysed the latest satellite image from the city in southern Gaza.
# See key moments in Alexei Navalny's career as an outspoken critic of President Putin.
# Yulia Navalnaya tells a conference in Munich she doesn't know whether the "horrible news" is true.
# Russian opposition politician Alexei Navalny has died in jail, prison authorities say.
# The Duke and Duchess of Sussex visited the training camp for the 2025 Invictus Games on Wednesday.
# The driver was killed and five others injured when a vehicle collided into an emergency ward in Texas.
# Inflation is down and "vibes" are up - but younger Americans especially remain sceptical after the pain of soaring prices.
# Tala Abu Nahla and her family have finally made it to Cairo - now the work to rebuild their lives begins.
# The Kenyan and Nigerian presidents face domestic criticism for their frequent trips abroad.
# In a country where dissent has been silenced, just laying flowers is an act of courage, writes Steve Rosenberg.
# The director of the 2022 Oscar-winning film speaks of his shock at the death of Alexei Navalny.
#
#
# Elements with class 'kTrQIN':
# The 'principled and fearless' Yulia Navalnaya
# Crew abandon cargo ship after attack off Yemen
# Cape Town stink blamed on cattle ship
# Dozens shot dead in Papua New Guinea ambush
# The 'principled and fearless' Yulia Navalnaya
# Israel's Rafah deadline raises stakes as Ramadan approaches
# Israeli PM 'missed chance' to cut off Hamas cash
# Crew abandon cargo ship after attack off Yemen
# Landslide kills 25 after heavy snow in Afghanistan
# Alert as torrential rains hit Bolivia, killing dozens
# Poland spyware inquiry to quiz former ministers
# Huge explosions as Israel strikes southern Lebanon
# 'Lose-lose' anxiety marks global security talks in Munich
# Tel Aviv protesters call on Netanyahu to resign
# Gaza ceasefire talks not very promising, says Qatar
# ‘Without painkillers, we leave patients to scream for hours’
# Fears for patients as Israel hospital raid continues
# Rafah images show huge blast craters close to camps
# Arrested and poisoned: See Navalny's moments of defiance
# Watch Yulia Navalnaya speak following report of husband's death
# Watch: Navalny seen in video link a day before his reported death
# Prince Harry tries a sit-ski on the slopes in Canada
# Video shows chaos after car crashes into hospital
# Voters feel better about the economy. Will it help Biden?
# Relief and guilt after Gazans find safety in Egypt
# Africa's 'flying presidents' under fire for foreign trips
# Rosenberg: Dissent takes courage - and Navalny supporters are defiant
# The Oscar-winning film that captured Navalny's life and future death
#
#
# Elements with class 'dJMMNx':
# In a video message, Yulia Navalnaya also accused the Kremlin of being behind her husband's death in a Siberian jail.
#
#
# Elements with class 'crzIlm':
# Navalny's grieving widow vows to continue his work

# %%
import requests
from bs4 import BeautifulSoup

def get_bbc_news_topics():
    url = 'https://www.bbc.com/news'
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        topics = []

        # Find topics under the 'News' section
        news_section = soup.find('a', {'href': '/news'})
        if news_section:
            topic_list = news_section.find_next('ul')
            if topic_list:
                topics = [(index + 1, topic.text, topic['href']) for index, topic in enumerate(topic_list.find_all('a'))]

        return topics

    else:
        print(f"Error: Unable to fetch topics. Status code: {response.status_code}")
        return []

def scrape_with_classes(soup, classes):
    scraped_data = []
    for class_name in classes:
        elements = soup.find_all(class_=class_name)
        if elements:
            for element in elements:
                scraped_data.append(element.get_text(strip=True))

    return scraped_data

def compare_statement(statement, scraped_data):
    for data in scraped_data:
        if statement.lower() in data.lower():
            return True
    return False

if __name__ == "__main__":
    # Get available topics
    topics = get_bbc_news_topics()

    if not topics:
        print("No topics found. Exiting.")
    else:
        # Display available topics to the user
        print("Available topics:")
        for topic in topics:
            print(f"{topic[0]}. {topic[1]} - URL: https://www.bbc.com{topic[2]}")

        # Ask the user to choose a topic
        try:
            user_choice = input("Enter the number corresponding to the desired topic: ")
            selected_topic = topics[int(user_choice) - 1]

            print(f"You selected: {selected_topic[1]} - URL: https://www.bbc.com{selected_topic[2]}")
            topic_url = f'https://www.bbc.com{selected_topic[2]}'

            # Make a request for the topic page
            topic_response = requests.get(topic_url)

            if topic_response.status_code == 200:
                soup = BeautifulSoup(topic_response.text, 'html.parser')

                # Classes to check
                classes_to_check = ["gclMev", "dEAAFJ", "czRLo", "jqwZKz", "kTrQIN", "dJMMNx", "crzIlm"]

                # Scrape elements with specified classes
                scraped_data = scrape_with_classes(soup, classes_to_check)

                # Ask the user to enter a statement for comparison
                user_statement = input("Enter the statement to verify: ")

                # Compare the user's statement with the scraped data
                if compare_statement(user_statement, scraped_data):
                    print(f"The statement '{user_statement}' is found on the page. It might be legitimate.")
                else:
                    print(f"The statement '{user_statement}' is not found on the page. It might not be legitimate.")

            else:
                print(f"Error: Unable to fetch topic page. Status code: {topic_response.status_code}")

        except (ValueError, IndexError):
            print("Invalid choice. Please enter a valid topic number.")
# Out:
# Available topics:
# 1. Israel-Gaza War - URL: https://www.bbc.com/news/topics/c2vdnvdg6xxt
# 2. War in Ukraine - URL: https://www.bbc.com/news/war-in-ukraine
# 3. World - URL: https://www.bbc.com/news/world
# 4. US & Canada - URL: https://www.bbc.com/news/us-canada
# 5. UK - URL: https://www.bbc.com/news/uk
# 6. In Pictures - URL: https://www.bbc.com/news/in_pictures
# 7. BBC Verify - URL: https://www.bbc.com/news/reality_check
# Enter the number corresponding to the desired topic: 3
# You selected: World - URL: https://www.bbc.com/news/world
# Enter the statement to verify: Protesters in Tel Aviv Tel Aviv protesters call on Netanyahu to resign The Israeli prime minister's popularity has declined among Israelis after the 7 October Hamas attacks.
# The statement 'Protesters in Tel Aviv Tel Aviv protesters call on Netanyahu to resign The Israeli prime minister's popularity has declined among Israelis after the 7 October Hamas attacks.' is not found on the page. It might not be legitimate.

# %%
import requests
from bs4 import BeautifulSoup

def get_bbc_news_topics():
    url = 'https://www.bbc.com/news'
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        topics = []

        # Find topics under the 'News' section
        news_section = soup.find('a', {'href': '/news'})
        if news_section:
            topic_list = news_section.find_next('ul')
            if topic_list:
                topics = [(index + 1, topic.text, topic['href']) for index, topic in enumerate(topic_list.find_all('a'))]

        return topics

    else:
        print(f"Error: Unable to fetch topics. Status code: {response.status_code}")
        return []

def scrape_with_classes(soup, classes):
    scraped_data = {}
    for class_name in classes:
        elements = soup.find_all(class_=class_name)
        if elements:
            scraped_data[class_name] = [element.get_text(strip=True) for element in elements]

    return scraped_data

def compare_statement(statement, scraped_data):
    for class_name, data_list in scraped_data.items():
        for data in data_list:
            if statement.lower() in data.lower():
                return class_name, data
    return None, None

if __name__ == "__main__":
    # Get available topics
    topics = get_bbc_news_topics()

    if not topics:
        print("No topics found. Exiting.")
    else:
        # Display available topics to the user
        print("Available topics:")
        for topic in topics:
            print(f"{topic[0]}. {topic[1]} - URL: https://www.bbc.com{topic[2]}")

        # Ask the user to choose a topic
        try:
            user_choice = input("Enter the number corresponding to the desired topic: ")
            selected_topic = topics[int(user_choice) - 1]

            print(f"You selected: {selected_topic[1]} - URL: https://www.bbc.com{selected_topic[2]}")
            topic_url = f'https://www.bbc.com{selected_topic[2]}'

            # Make a request for the topic page
            topic_response = requests.get(topic_url)

            if topic_response.status_code == 200:
                soup = BeautifulSoup(topic_response.text, 'html.parser')

                # Classes to check
                classes_to_check = ["gclMev", "dEAAFJ", "czRLo", "jqwZKz", "kTrQIN", "dJMMNx", "crzIlm"]

                # Scrape elements with specified classes
                scraped_data = scrape_with_classes(soup, classes_to_check)

                # Ask the user to enter a statement for comparison
                user_statement = input("Enter the statement to verify: ")

                # Compare the user's statement with the scraped data
                matched_class, matched_data = compare_statement(user_statement, scraped_data)

                if matched_class is not None and matched_data is not None:
                    print(f"The statement '{user_statement}' is found in the context of class '{matched_class}':")
                    print(matched_data)
                    print("Statement verified and legitimate!")
                else:
                    print(f"The statement '{user_statement}' is not found on the page. It might not be legitimate.")

            else:
                print(f"Error: Unable to fetch topic page. Status code: {topic_response.status_code}")

        except (ValueError, IndexError):
            print("Invalid choice. Please enter a valid topic number.")
# Out:
# Available topics:
# 1. Israel-Gaza War - URL: https://www.bbc.com/news/topics/c2vdnvdg6xxt
# 2. War in Ukraine - URL: https://www.bbc.com/news/war-in-ukraine
# 3. World - URL: https://www.bbc.com/news/world
# 4. US & Canada - URL: https://www.bbc.com/news/us-canada
# 5. UK - URL: https://www.bbc.com/news/uk
# 6. In Pictures - URL: https://www.bbc.com/news/in_pictures
# 7. BBC Verify - URL: https://www.bbc.com/news/reality_check
# Enter the number corresponding to the desired topic: 3
# You selected: World - URL: https://www.bbc.com/news/world
# Enter the statement to verify: Protesters in Tel Aviv Tel Aviv protesters call on Netanyahu to resign The Israeli prime minister's popularity has declined among Israelis after the 7 October Hamas attacks.
# The statement 'Protesters in Tel Aviv Tel Aviv protesters call on Netanyahu to resign The Israeli prime minister's popularity has declined among Israelis after the 7 October Hamas attacks.' is not found on the page. It might not be legitimate.

# %%
import requests
from bs4 import BeautifulSoup
from difflib import get_close_matches

def get_bbc_news_topics():
    url = 'https://www.bbc.com/news'
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        topics = []

        # Find topics under the 'News' section
        news_section = soup.find('a', {'href': '/news'})
        if news_section:
            topic_list = news_section.find_next('ul')
            if topic_list:
                topics = [(index + 1, topic.text, topic['href']) for index, topic in enumerate(topic_list.find_all('a'))]

        return topics

    else:
        print(f"Error: Unable to fetch topics. Status code: {response.status_code}")
        return []

def scrape_with_classes(soup, classes):
    scraped_data = {}
    for class_name in classes:
        elements = soup.find_all(class_=class_name)
        if elements:
            scraped_data[class_name] = [element.get_text(strip=True) for element in elements]

    return scraped_data

def compare_statement(statement, scraped_data):
    matches = get_close_matches(statement.lower(), [data.lower() for data_list in scraped_data.values() for data in data_list], n=1, cutoff=0.8)

    if matches:
        for class_name, data_list in scraped_data.items():
            for data in data_list:
                if matches[0] in data.lower():
                    return class_name, data
    return None, None

def scrape_and_verify(user_statement, url, classes_to_check):
    try:
        # Make a request for the selected news page
        response = requests.get(url)

        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')

            # Scrape elements with specified classes
            scraped_data = scrape_with_classes(soup, classes_to_check)

            # Compare the user's statement with the scraped data
            matched_class, matched_data = compare_statement(user_statement, scraped_data)

            if matched_class is not None and matched_data is not None:
                print(f"The statement '{user_statement}' is found in the context of class '{matched_class}':")
                print(matched_data)
                print("Statement verified and legitimate!")
            else:
                if scraped_data:
                    print(f"The statement '{user_statement}' is not found. Similar data includes:")
                    for class_name, data_list in scraped_data.items():
                        print(f"Class '{class_name}': {data_list}")
                else:
                    print("No data found on the page.")

        else:
            print(f"Error: Unable to fetch news page. Status code: {response.status_code}")

    except Exception as e:
        print(f"An error occurred: {e}")

if __name__ == "__main__":
    # Get available news categories
    topics = get_bbc_news_topics()

    if not topics:
        print("No news categories found. Exiting.")
    else:
        # Display available news categories to the user
        print("Available news categories:")
        for topic in topics:
            print(f"{topic[0]}. {topic[1]} - URL: https://www.bbc.com{topic[2]}")

        # Ask the user to choose a news category
        try:
            user_choice = input("Enter the number corresponding to the desired news category: ")
            selected_topic = topics[int(user_choice) - 1]
            news_category_url = f'https://www.bbc.com{selected_topic[2]}'

            # Replace 'your_link_class' with the actual class name for the links to other pages
            classes_to_check = ["gclMev", "dEAAFJ", "czRLo", "jqwZKz", "kTrQIN", "dJMMNx", "crzIlm"]

            # Ask the user to input the statement for verification
            user_statement = input("Enter the statement to verify: ")

            # Scrape content and verify statement
            scrape_and_verify(user_statement, news_category_url, classes_to_check)

        except (ValueError, IndexError):
            print("Invalid choice. Please enter a valid news category number.")
# Out:
# Available news categories:
# 1. Israel-Gaza War - URL: https://www.bbc.com/news/topics/c2vdnvdg6xxt
# 2. War in Ukraine - URL: https://www.bbc.com/news/war-in-ukraine
# 3. World - URL: https://www.bbc.com/news/world
# 4. US & Canada - URL: https://www.bbc.com/news/us-canada
# 5. UK - URL: https://www.bbc.com/news/uk
# 6. In Pictures - URL: https://www.bbc.com/news/in_pictures
# 7. BBC Verify - URL: https://www.bbc.com/news/reality_check
# Enter the number corresponding to the desired news category: 5
# Enter the statement to verify: uk
# The statement 'uk' is not found. Similar data includes:
# Class 'gclMev': ['She also told detectives she debated handing herself in two weeks after their baby died.', "The government says it will help 'minimise disruption and improve behaviour in classrooms' in England.", 'A unique case raised complex questions about whether an asylum seeker could be blamed for drownings in 2022.', 'A man has been found guilty of the manslaughter of four migrants in the English Channel.', "Stella Assange said an emergency injunction could be sought if he loses Tuesday's court case.", 'The virus is usually spread by midge bites and can affect cows, sheep and goats.', 'Leaked documents show that UK Special Forces had veto power over applications from Afghan counterparts.', 'Karen Findlay is targeted by "homophobic, sexist" abuse after her move to the British Transport Police.', 'It means those on the earliest visas will be allowed to stay in the UK until at least September 2026.']
# Class 'dEAAFJ': ['Constance Marten told to say baby died of cot death', 'Schools given new guidance on stopping phone use', 'The unprecedented case of a migrant manslaughter trial', 'Video shows the moment sinking dinghy is rescued', "Assange's wife says he 'won't survive US extradition'", 'Bluetongue virus restriction lifted in Norfolk', 'Special forces stopped Afghan troops settling in UK', 'Police chiefs condemn abuse of transport commander', 'Ukraine visa schemes to be extended by 18 months']
# Class 'czRLo': ['The search for the missing two-year-old child continues, with additional specialist teams in place.', 'From the summer, planning permission may be needed to turn homes into new short-term lets.']
# Class 'jqwZKz': ['The business secretary and ex-Post Office chair have clashed over comments about compensation.', 'Opposition parties say closing the scheme "without warning" is "cruel".', 'The business secretary and ex-Post Office chair have clashed over comments about compensation.', 'The children, aged seven, three and nine months old, were discovered by officers on Sunday.', 'Oliver Glasner replaces Roy Hodgson, who stepped down on Monday, at the Premier League club.', 'Opposition parties say closing the scheme "without warning" is "cruel".', 'The second challenge to plans for a two-mile tunnel at the World Heritage site has been dismissed.', 'She also told detectives she debated handing herself in two weeks after their baby died.', 'Party bags of cannisters and other illegal drugs were found after a car was pulled over by police.', 'Patients are facing delays for ongoing cancer care, heart check-ups and eye treatment in England.', 'The comedian will perform at the opening of the 23,500-seater Co-op Live venue in Manchester.', "BBC Weather's Kawser Quamer went into a bit too much detail in her forecast on North West Tonight.", "Londoner Tarinn Callender plays Bronco Billy in a new musical based on Clint Eastwood's 1980 film.", 'The calf was captured on film being taught by their pod to hunt seabirds off the coast of the Scottish Islands.', 'The Duke and Duchess of Sussex visited the training camp for the 2025 Invictus Games on Wednesday.', 'Laughter and tears for winners at the Bafta Awards 2024 in London.', 'A unique case raised complex questions about whether an asylum seeker could be blamed for drownings in 2022.', 'Karen Cook has a rare condition called pain hyperacusis which causes crippling and debilitating pain.', 'Big names from films like Barbie, Oppenheimer and Saltburn step out at the British awards ceremony.', 'Marieme and Ndeye, seven, were not expected to survive for more than a few days after they were born.', 'The children, aged seven, three and nine months old, were discovered by officers on Sunday.', 'Freya delivered her 9lbs 8oz son with no pain relief while her mum drove her to hospital.', 'Work on hospitals, surgeries and treatment centres have been delayed or paused due to budget pressures.', 'The vote in favour of a strike could see junior doctors take part in a 24-hour walkout in March.', 'The search for the missing two-year-old child continues, with additional specialist teams in place.']
# Class 'kTrQIN': ['Row deepens between Badenoch and ex-Post Office chair', 'Ukraine family visa scheme closes to new applicants', 'Father tried to rescue son, 2, who fell into river', 'New controls on holiday lets to be introduced', 'Row deepens between Badenoch and ex-Post Office chair', 'Baby among three children found dead in house', 'Crystal Palace appoint Glasner as new manager', 'Ukraine family visa scheme closes to new applicants', 'Campaigners lose challenge against Stonehenge tunnel', 'Constance Marten told to say baby died of cot death', 'First jailing over intention to supply nitrous oxide', 'The NHS hidden waiting lists terrifying patients', 'Peter Kay to perform at opening of new arena', 'Moment surprise party is accidentally revealed on TV', 'Wild West comes to the West End', 'Video shows orca learning to hunt birds off Orkney', 'Prince Harry tries a sit-ski on the slopes in Canada', 'Watch Baftas 2024 best bits... in two minutes', 'The unprecedented case of a migrant manslaughter trial', "'My condition means hearing my children's laughter is like torture'", 'In pictures: Stars on the Baftas red carpet', 'Conjoined twins given days to live are proving world wrong', 'Baby among three children found dead in house', 'Mum gives birth in traffic jam on way to hospital', 'All new NHS building projects in Scotland on hold', 'NI junior doctors vote for strike action over pay', 'Father tried to rescue son, 2, who fell into river']
# Class 'dJMMNx': ['Four people drowned when an overcrowded dinghy steered by Ibrahima Bah began to sink on a crossing.']
# Class 'crzIlm': ['Boat pilot guilty over Channel migrant deaths']

# %%
import requests
from bs4 import BeautifulSoup
from difflib import get_close_matches

def get_bbc_news_topics():
    url = 'https://www.bbc.com/news'
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        topics = []

        # Find topics under the 'News' section
        news_section = soup.find('a', {'href': '/news'})
        if news_section:
            topic_list = news_section.find_next('ul')
            if topic_list:
                topics = [(index + 1, topic.text, topic['href']) for index, topic in enumerate(topic_list.find_all('a'))]

        return topics

    else:
        print(f"Error: Unable to fetch topics. Status code: {response.status_code}")
        return []

def scrape_with_classes(soup, classes):
    scraped_data = {}
    for class_name in classes:
        elements = soup.find_all(class_=class_name)
        if elements:
            scraped_data[class_name] = elements

    return scraped_data

def find_links_in_context(user_statement, soup, classes_to_check):
    links = []

    for class_name in classes_to_check:
        elements = soup.find_all(class_=class_name)
        for element in elements:
            if user_statement.lower() in element.get_text(strip=True).lower():
                link = element.find('a')
                if link:
                    links.append(link.get('href'))

    return links

def compare_statement(statement, scraped_data):
    matches = get_close_matches(statement.lower(), [data.get_text(strip=True).lower() for data_list in scraped_data.values() for data in data_list], n=1, cutoff=0.8)

    if matches:
        for class_name, data_list in scraped_data.items():
            for data in data_list:
                if matches[0] in data.get_text(strip=True).lower():
                    return class_name, data
    return None, None

def scrape_and_verify(user_statement, url, classes_to_check):
    try:
        # Make a request for the selected news page
        response = requests.get(url)

        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')

            # Scrape elements with specified classes
            scraped_data = scrape_with_classes(soup, classes_to_check)

            # Find links in the context of the user's statement
            links = find_links_in_context(user_statement, soup, classes_to_check)

            # Compare the user's statement with the scraped data
            matched_class, matched_data = compare_statement(user_statement, scraped_data)

            if matched_class is not None and matched_data is not None:
                print(f"The statement '{user_statement}' is found in the context of:")
                print(matched_data.get_text(strip=True))
                print("Statement verified and legitimate!")
                if links:
                    print(f"Links related to the statement:")
                    for link in links:
                        print(link)
            else:
                if scraped_data:
                    print(f"The statement '{user_statement}' is not found. Similar data includes:")
                    for class_name, data_list in scraped_data.items():
                        for data in data_list:
                            print(f"Context: {data.get_text(strip=True)}")
                            link = data.find('a')
                            if link:
                                print(f"Link: {link.get('href')}")
                    if links:
                        print(f"Links related to the statement:")
                        for link in links:
                            print(link)
                else:
                    print("No data found on the page.")

        else:
            print(f"Error: Unable to fetch news page. Status code: {response.status_code}")

    except Exception as e:
        print(f"An error occurred: {e}")

if __name__ == "__main__":
    # Get available news categories
    topics = get_bbc_news_topics()

    if not topics:
        print("No news categories found. Exiting.")
    else:
        # Display available news categories to the user
        print("Available news categories:")
        for topic in topics:
            print(f"{topic[0]}. {topic[1]} - URL: https://www.bbc.com{topic[2]}")

        # Ask the user to choose a news category
        try:
            user_choice = input("Enter the number corresponding to the desired news category: ")
            selected_topic = topics[int(user_choice) - 1]
            news_category_url = f'https://www.bbc.com{selected_topic[2]}'

            # Replace 'your_link_class' with the actual class name for the links to other pages
            classes_to_check = ["gclMev", "dEAAFJ", "czRLo", "jqwZKz", "kTrQIN", "dJMMNx", "crzIlm"]

            # Ask the user to input the statement for verification
            user_statement = input("Enter the statement to verify: ")

            # Scrape content and verify statement
            scrape_and_verify(user_statement, news_category_url, classes_to_check)

        except (ValueError, IndexError):
            print("Invalid choice. Please enter a valid news category number.")
# Out:
# Available news categories:
# 1. Israel-Gaza War - URL: https://www.bbc.com/news/topics/c2vdnvdg6xxt
# 2. War in Ukraine - URL: https://www.bbc.com/news/war-in-ukraine
# 3. World - URL: https://www.bbc.com/news/world
# 4. US & Canada - URL: https://www.bbc.com/news/us-canada
# 5. UK - URL: https://www.bbc.com/news/uk
# 6. In Pictures - URL: https://www.bbc.com/news/in_pictures
# 7. BBC Verify - URL: https://www.bbc.com/news/reality_check
# Enter the number corresponding to the desired news category: 1
# Enter the statement to verify: Tala and Yazid Relief and guilt after Gazans find safety in Egypt Tala Abu Nahla and her family have finally made it to Cairo - now the work to rebuild their lives begins.
# The statement 'Tala and Yazid Relief and guilt after Gazans find safety in Egypt Tala Abu Nahla and her family have finally made it to Cairo - now the work to rebuild their lives begins.' is not found. Similar data includes:
# Context: Israel's military says it hit weapons depots in response to a drone launched by Hezbollah.
# Context: Indirect talks between Israel and Hamas have not brought the war to an end - and a pivotal few weeks looms.
# Context: Former spy chief tells BBC that Benjamin Netanyahu didn't act on advice to hit the group's money streams.
# Context: Its gross domestic product contracted by far more than expected in the wake of the conflict with Gaza.
# Context: The conflicts in Gaza and Ukraine underline deepening geopolitical tensions and economic uncertainties.
# Context: A war cabinet member says unless Hamas frees all hostages by 10 March an assault will begin in Rafah.
# Context: Israeli forces say intelligence suggested hostages were being held at the Nasser site by Hamas.
# Context: Labour leader Sir Keir Starmer calls for a lasting ceasefire in the Israel-Gaza conflict.
# Context: Tala Abu Nahla and her family have finally made it to Cairo - now the work to rebuild their lives begins.
# Context: Huge explosions as Israel strikes southern Lebanon
# Context: Israel's Rafah deadline raises stakes as Ramadan approaches
# Context: Israeli PM 'missed chance' to cut off Hamas cash
# Context: Israel's economy shrinks sharply on Gaza war
# Context: 'Lose-lose' anxiety marks global security talks in Munich
# Context: Israel indicates deadline for offensive in Rafah
# Context: WHO says Gaza hospital raided by IDF not functional
# Context: Starmer: Gaza ceasefire 'must happen now'
# Context: Relief and guilt after Gazans find safety in Egypt
# Context: Israel's PM Benjamin Netanyahu vows to carry on the war against Hamas regardless of international pressure.
# Context: Brazil's president is accused by Israel of "crossing a red line" after he made the comparison in a speech.
# Context: A war cabinet member says unless Hamas frees all hostages by 10 March an assault will begin in Rafah.
# Context: Tala Abu Nahla and her family have finally made it to Cairo - now the work to rebuild their lives begins.
# Context: A war cabinet member says unless Hamas frees all hostages by 10 March an assault will begin in Rafah.
# Context: Doctors in Gaza say the healthcare system is broken and they are operating on people without anaesthetic.
# Context: Israeli forces say intelligence suggested hostages were being held at the Nasser site by Hamas.
# Context: Tala Abu Nahla and her family have finally made it to Cairo - now the work to rebuild their lives begins.
# Context: Why did Hamas attack Israel, and what has happened in Gaza since the 7 October raid?
# Context: Find out how much has changed in the Gaza Strip since Israel began its military response to Hamas's attacks on 7 October.
# Context: The Houthis in Yemen have vowed to attack all ships in the Red Sea that are linked to Israel.
# Context: Supply chains face disruption due to vessels diverting away from the key shipping route.
# Context: Tensions between Israel and the Palestinians date back decades, but what are the key issues?
# Context: Reports claim the work could be in preparation for Palestinian refugees - something Egypt publicly denies.
# Context: BBC Verify analyses footage from the Nasser hospital in southern Gaza as Israeli forces raid the complex.
# Context: BBC Verify has analysed the latest satellite image from the city in southern Gaza.
# Context: Jeremy Bowen looks at Gaza's humanitarian crisis and a growing panic in Rafah over a looming Israeli offensive.
# Context: BBC's Paul Adams asks whether US strikes on Iraq and Syria made a regional conflagration more likely.
# Context: BBC News Arabic followed three first responders working under intense bombardment in the first month of the war.
# Context: The Israeli prime minister's popularity has declined among Israelis after the 7 October Hamas attacks.
# Context: It is thought more than 100 Israelis are still being held hostage in Gaza after the 7 October attacks.
# Context: Some 19,000 children have been orphaned by the war, or have no adults to look after them, says the UN.
# Context: Eli Albag is haunted by the ordeal of his daughter Liri, held hostage in Gaza, as he campaigns for more pressure on Qatar.
# Context: Israel indicates deadline for offensive in Rafah
# Context: Relief and guilt after Gazans find safety in Egypt
# Context: Gaza ceasefire talks not very promising, says Qatar
# Context: Israel condemns Lula likening Gaza war to Holocaust
# Context: Israel indicates deadline for offensive in Rafah
# Context: ‘Without painkillers, we leave patients to scream for hours’
# Context: WHO says Gaza hospital raided by IDF not functional
# Context: Relief and guilt after Gazans find safety in Egypt
# Context: Why are Israel and Hamas fighting in Gaza?
# Context: Gaza Strip in maps: How life has changed in four months
# Context: Who are the Houthis attacking Red Sea ships?
# Context: What do Red Sea assaults mean for global trade?
# Context: Israel Gaza war: What are the key issues?
# Context: Satellite images show construction on Egypt-Gaza border
# Context: What we can see in video from Nasser hospital raid
# Context: Rafah images show huge blast craters close to camps
# Context: Israel-Gaza war: Death and Israel’s search for ‘total victory’
# Context: What are routes out of this 'dangerous moment' in Middle East?
# Context: Exclusive video: Trauma at every turn for Gaza’s exhausted paramedics
# Context: Tel Aviv protesters call on Netanyahu to resign
# Context: Stories of the hostages taken by Hamas from Israel
# Context: Injured, hungry and alone - the Gazan children orphaned by war
# Context: 'I go to sleep a dead man' - father's pain at daughter's captivity in Gaza
# Context: Former spy chief tells BBC that Benjamin Netanyahu didn't act on advice to hit the group's money streams.
# Context: People who survived the 7 October attacks in Israel by Hamas describe how events unfolded
# Context: Israeli PM 'missed chance' to cut off Hamas cash
# Context: The Documentary Podcast: The Israeli hostages

# %%
import requests
from bs4 import BeautifulSoup
from fuzzywuzzy import fuzz

def get_bbc_news_topics():
    url = 'https://www.bbc.com/news'
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        topics = []

        # Find topics under the 'News' section
        news_section = soup.find('a', {'href': '/news'})
        if news_section:
            topic_list = news_section.find_next('ul')
            if topic_list:
                topics = [(index + 1, topic.text, topic['href']) for index, topic in enumerate(topic_list.find_all('a'))]

        return topics

    else:
        print(f"Error: Unable to fetch topics. Status code: {response.status_code}")
        return []

def scrape_with_classes(soup, classes):
    scraped_data = {}
    for class_name in classes:
        elements = soup.find_all(class_=class_name)
        if elements:
            scraped_data[class_name] = [element.get_text(strip=True) for element in elements]

    return scraped_data

def find_parent_link(element):
    # Traverse the ancestors to find an href
    current_element = element
    while current_element:
        if 'href' in current_element.attrs:
            return current_element['href']
        current_element = current_element.find_parent()

    return 'Link not found'

def compare_statement(user_statement, scraped_data, soup):
    matches = {}
    for class_name, data_list in scraped_data.items():
        for data in data_list:
            # Use fuzzy matching to handle typos or errors
            similarity_ratio = fuzz.token_set_ratio(user_statement.lower(), data.lower())
            if similarity_ratio > 90:  # Adjust the threshold as needed
                matches[class_name] = {
                    'context': data,
                    'similarity_ratio': similarity_ratio,
                    'parent_link': find_parent_link(soup.find(class_=class_name)),
                }

    return matches

def print_matched_results(matches):
    for class_name, match_info in matches.items():
        context = match_info['context']
        similarity_ratio = match_info['similarity_ratio']
        parent_link = match_info['parent_link']
        print(f"Context: {context} - Similarity: {similarity_ratio}% - Parent Link: {parent_link}")

def scrape_and_verify(user_statement, news_category_url, classes_to_check):
    # Make a request for the news category page
    news_category_response = requests.get(news_category_url)

    if news_category_response.status_code == 200:
        soup = BeautifulSoup(news_category_response.text, 'html.parser')

        # Scrape elements with specified classes
        scraped_data = scrape_with_classes(soup, classes_to_check)

        # Compare the user's statement with the scraped data
        matches = compare_statement(user_statement, scraped_data, soup)

        if matches:
            print("The following contexts were found:")
            print_matched_results(matches)
            print("Statement verified and legitimate!")
        else:
            print("No matching context found. The statement might not be legitimate.")

    else:
        print(f"Error: Unable to fetch news category page. Status code: {news_category_response.status_code}")

if __name__ == "__main__":
    # Get available news categories
    topics = get_bbc_news_topics()

    if not topics:
        print("No news categories found. Exiting.")
    else:
        # Display available news categories to the user
        print("Available news categories:")
        for topic in topics:
            print(f"{topic[0]}. {topic[1]} - URL: https://www.bbc.com{topic[2]}")

        # Ask the user to choose a news category
        try:
            user_choice = input("Enter the number corresponding to the desired news category: ")
            selected_topic = topics[int(user_choice) - 1]

            print(f"You selected: {selected_topic[1]} - URL: https://www.bbc.com{selected_topic[2]}")
            news_category_url = f'https://www.bbc.com{selected_topic[2]}'

            # Ask the user to enter a statement for verification
            user_statement = input("Enter the statement to verify: ")

            # Specify classes to check on the news pages
            classes_to_check = ["gclMev", "dEAAFJ", "czRLo", "jqwZKz", "kTrQIN", "dJMMNx", "crzIlm"]

            # Scrape and verify the user's statement
            scrape_and_verify(user_statement, news_category_url, classes_to_check)

        except (ValueError, IndexError):
            print("Invalid choice.")
# Out:
# Available news categories:
# 1. Israel-Gaza War - URL: https://www.bbc.com/news/topics/c2vdnvdg6xxt
# 2. War in Ukraine - URL: https://www.bbc.com/news/war-in-ukraine
# 3. World - URL: https://www.bbc.com/news/world
# 4. US & Canada - URL: https://www.bbc.com/news/us-canada
# 5. UK - URL: https://www.bbc.com/news/uk
# 6. In Pictures - URL: https://www.bbc.com/news/in_pictures
# 7. BBC Verify - URL: https://www.bbc.com/news/reality_check
# Enter the number corresponding to the desired news category: 2
# You selected: War in Ukraine - URL: https://www.bbc.com/news/war-in-ukraine
# Enter the statement to verify: ukraine russia
# The following contexts were found:
# Context: With Western supplies to Ukraine faltering, Russia is making its size matter but the outcome is far from certain. - Similarity: 100% - Parent Link: /news/uk-england-merseyside-68336591
# Context: Is Russia turning the tide in Ukraine? - Similarity: 100% - Parent Link: /news/uk-england-merseyside-68336591
# Context: With Western supplies to Ukraine faltering, Russia is making its size matter but the outcome is far from certain. - Similarity: 100% - Parent Link: /news/world-europe-68325022
# Context: Is Russia turning the tide in Ukraine? - Similarity: 100% - Parent Link: /news/world-europe-68325022
# Statement verified and legitimate!

# %%
import requests
from bs4 import BeautifulSoup
from fuzzywuzzy import fuzz

def get_bbc_news_topics():
    url = 'https://www.bbc.com/news'
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        topics = []

        # Find topics under the 'News' section
        news_section = soup.find('a', {'href': '/news'})
        if news_section:
            topic_list = news_section.find_next('ul')
            if topic_list:
                topics = [(index + 1, topic.text, topic['href']) for index, topic in enumerate(topic_list.find_all('a'))]

        return topics

    else:
        print(f"Error: Unable to fetch topics. Status code: {response.status_code}")
        return []

def scrape_with_classes(soup, classes):
    scraped_data = {}
    for class_name in classes:
        elements = soup.find_all(class_=class_name)
        if elements:
            scraped_data[class_name] = [element.get_text(strip=True) for element in elements]

    return scraped_data

def compare_statement(statement, scraped_data):
    matched_data = []
    for class_name, data_list in scraped_data.items():
        for data in data_list:
            ratio = fuzz.partial_ratio(statement.lower(), data.lower())
            if ratio >= 80:
                matched_data.append((class_name, data))

    return matched_data

if __name__ == "__main__":
    # Get available topics
    topics = get_bbc_news_topics()

    if not topics:
        print("No topics found. Exiting.")
    else:
        # Display available topics to the user
        print("Available topics:")
        for topic in topics:
            print(f"{topic[0]}. {topic[1]} - URL: https://www.bbc.com{topic[2]}")

        # Ask the user to choose a topic
        try:
            user_choice = input("Enter the number corresponding to the desired topic: ")
            selected_topic = topics[int(user_choice) - 1]

            print(f"You selected: {selected_topic[1]} - URL: https://www.bbc.com{selected_topic[2]}")
            topic_url = f'https://www.bbc.com{selected_topic[2]}'

            # Make a request for the topic page
            topic_response = requests.get(topic_url)

            if topic_response.status_code == 200:
                soup = BeautifulSoup(topic_response.text, 'html.parser')

                # Classes to check
                classes_to_check = ["gclMev", "dEAAFJ", "czRLo", "jqwZKz", "kTrQIN", "dJMMNx", "crzIlm"]

                # Scrape elements with specified classes
                scraped_data = scrape_with_classes(soup, classes_to_check)

                # Ask the user to enter a statement for comparison
                user_statement = input("Enter the statement to verify: ")

                # Compare the user's statement with the scraped data
                matched_data = compare_statement(user_statement, scraped_data)

                if matched_data:
                    print("Matching contexts found:")
                    for match in matched_data:
                        class_name, data = match
                        parent_link = soup.find(class_=class_name).find_parent('a')['href']
                        print(f"Class: {class_name}, Data: {data}, Parent Link: https://www.bbc.com{parent_link}")
                else:
                    print("No matching context found. The statement might not be legitimate.")

            else:
                print(f"Error: Unable to fetch topic page. Status code: {topic_response.status_code}")

        except (ValueError, IndexError):
            print("Invalid choice. Please enter a valid topic number.")
# Out:
# Available topics:
# 1. Israel-Gaza War - URL: https://www.bbc.com/news/topics/c2vdnvdg6xxt
# 2. War in Ukraine - URL: https://www.bbc.com/news/war-in-ukraine
# 3. World - URL: https://www.bbc.com/news/world
# 4. US & Canada - URL: https://www.bbc.com/news/us-canada
# 5. UK - URL: https://www.bbc.com/news/uk
# 6. In Pictures - URL: https://www.bbc.com/news/in_pictures
# 7. BBC Verify - URL: https://www.bbc.com/news/reality_check
# Enter the number corresponding to the desired topic: 4
# You selected: US & Canada - URL: https://www.bbc.com/news/us-canada
# Enter the statement to verify: canada
# Matching contexts found:
# Class: jqwZKz, Data: Canada's wildfire season is not over, with dozens of winter fires still burning beneath the soil., Parent Link: https://www.bbc.com/news/world-us-canada-68336601
# Class: kTrQIN, Data: 'Zombie Fires' burning at an alarming rate in Canada, Parent Link: https://www.bbc.com/news/world-us-canada-68336601

# %%
import requests
from bs4 import BeautifulSoup
from fuzzywuzzy import fuzz

def get_bbc_news_topics():
    url = 'https://www.bbc.com/news'
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        topics = []

        # Find topics under the 'News' section
        news_section = soup.find('a', {'href': '/news'})
        if news_section:
            topic_list = news_section.find_next('ul')
            if topic_list:
                topics = [(index + 1, topic.text, topic['href']) for index, topic in enumerate(topic_list.find_all('a'))]

        return topics

    else:
        print(f"Error: Unable to fetch topics. Status code: {response.status_code}")
        return []

def scrape_with_classes(soup, classes):
    scraped_data = {}
    for class_name in classes:
        elements = soup.find_all(class_=class_name)
        if elements:
            scraped_data[class_name] = [element.get_text(strip=True) for element in elements]

    return scraped_data

def compare_statement(statement, scraped_data):
    matched_data = []
    for class_name, data_list in scraped_data.items():
        for data in data_list:
            ratio = fuzz.partial_ratio(statement.lower(), data.lower())
            if ratio >= 80:
                parent_link = soup.find(string=data).find_parent('a')['href']
                matched_data.append((f"https://www.bbc.com{parent_link}", data))

    return matched_data

if __name__ == "__main__":
    # Get available topics
    topics = get_bbc_news_topics()

    if not topics:
        print("No topics found. Exiting.")
    else:
        # Display available topics to the user
        print("Available topics:")
        for topic in topics:
            print(f"{topic[0]}. {topic[1]} - URL: https://www.bbc.com{topic[2]}")

        # Ask the user to choose a topic
        try:
            user_choice = input("Enter the number corresponding to the desired topic: ")
            selected_topic = topics[int(user_choice) - 1]

            print(f"You selected: {selected_topic[1]} - URL: https://www.bbc.com{selected_topic[2]}")
            topic_url = f'https://www.bbc.com{selected_topic[2]}'

            # Make a request for the topic page
            topic_response = requests.get(topic_url)

            if topic_response.status_code == 200:
                soup = BeautifulSoup(topic_response.text, 'html.parser')

                # Classes to check
                classes_to_check = ["gclMev", "dEAAFJ", "czRLo", "jqwZKz", "kTrQIN", "dJMMNx", "crzIlm"]

                # Scrape elements with specified classes
                scraped_data = scrape_with_classes(soup, classes_to_check)

                # Ask the user to enter a statement for comparison
                user_statement = input("Enter the statement to verify: ")

                # Compare the user's statement with the scraped data
                matched_data = compare_statement(user_statement, scraped_data)

                if matched_data:
                    print("Matching contexts found:")
                    for link, data in matched_data:
                        print(f"Link: {link} - Matched: {data}")
                else:
                    print("No matching context found. The statement might not be legitimate.")

            else:
                print(f"Error: Unable to fetch topic page. Status code: {topic_response.status_code}")

        except (ValueError, IndexError):
            print("Invalid choice. Please enter a valid topic number.")
# Out:
# Available topics:
# 1. Israel-Gaza War - URL: https://www.bbc.com/news/topics/c2vdnvdg6xxt
# 2. War in Ukraine - URL: https://www.bbc.com/news/war-in-ukraine
# 3. World - URL: https://www.bbc.com/news/world
# 4. US & Canada - URL: https://www.bbc.com/news/us-canada
# 5. UK - URL: https://www.bbc.com/news/uk
# 6. In Pictures - URL: https://www.bbc.com/news/in_pictures
# 7. BBC Verify - URL: https://www.bbc.com/news/reality_check
# Enter the number corresponding to the desired topic: 7
# You selected: BBC Verify - URL: https://www.bbc.com/news/reality_check
# Enter the statement to verify: President Putin waving at Moscow Victory Day parade Putin's Victory Day speech fact-checked President Putin made several claims about Ukraine and Nato in his speech at a military parade in Moscow.
# Matching contexts found:
# Link: https://www.bbc.com/news/61379405 - Matched: President Putin made several claims about Ukraine and Nato in his speech at a military parade in Moscow.
# Link: https://www.bbc.com/news/61379405 - Matched: Putin's Victory Day speech fact-checked

# %%
import requests
from bs4 import BeautifulSoup
from fuzzywuzzy import fuzz

def get_bbc_news_topics():
    url = 'https://www.bbc.com/news'
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        topics = []

        # Find topics under the 'News' section
        news_section = soup.find('a', {'href': '/news'})
        if news_section:
            topic_list = news_section.find_next('ul')
            if topic_list:
                topics = [(index + 1, topic.text, topic['href']) for index, topic in enumerate(topic_list.find_all('a'))]

        return topics

    else:
        print(f"Error: Unable to fetch topics. Status code: {response.status_code}")
        return []

def scrape_with_classes(soup, classes):
    scraped_data = {}
    for class_name in classes:
        elements = soup.find_all(class_=class_name)
        if elements:
            scraped_data[class_name] = [element.get_text(strip=True) for element in elements]

    return scraped_data

def compare_statement(statement, scraped_data, soup):
    matched_data = []
    for class_name, data_list in scraped_data.items():
        for data in data_list:
            ratio = fuzz.partial_ratio(statement.lower(), data.lower())
            if ratio >= 80:
                parent_link = soup.find(string=data).find_parent('a')
                if parent_link:
                    href = parent_link.get('href')
                    matched_data.append((f"https://www.bbc.com{href}", data))

    return matched_data

if __name__ == "__main__":
    # Get available topics
    topics = get_bbc_news_topics()

    if not topics:
        print("No topics found. Exiting.")
    else:
        # Display available topics to the user
        print("Available topics:")
        for topic in topics:
            print(f"{topic[0]}. {topic[1]} - URL: https://www.bbc.com{topic[2]}")

        # Ask the user to choose a topic
        try:
            user_choice = input("Enter the number corresponding to the desired topic: ")
            selected_topic = topics[int(user_choice) - 1]

            print(f"You selected: {selected_topic[1]} - URL: https://www.bbc.com{selected_topic[2]}")
            topic_url = f'https://www.bbc.com{selected_topic[2]}'

            # Make a request for the topic page
            topic_response = requests.get(topic_url)

            if topic_response.status_code == 200:
                soup = BeautifulSoup(topic_response.text, 'html.parser')

                # Classes to check
                classes_to_check = ["gclMev", "dEAAFJ", "czRLo", "jqwZKz", "kTrQIN", "dJMMNx", "crzIlm"]

                # Scrape elements with specified classes
                scraped_data = scrape_with_classes(soup, classes_to_check)

                # Ask the user to enter a statement for comparison
                user_statement = input("Enter the statement to verify: ")

                # Compare the user's statement with the scraped data
                matched_data = compare_statement(user_statement, scraped_data, soup)

                if matched_data:
                    print("Matching contexts found:")
                    for link, data in matched_data:
                        print(f"Link: {link} - Matched: {data}")
                else:
                    print("No matching context found. The statement might not be legitimate.")

            else:
                print(f"Error: Unable to fetch topic page. Status code: {topic_response.status_code}")

        except (ValueError, IndexError):
            print("Invalid choice. Please enter a valid topic number.")
# Out:
# Available topics:
# 1. Israel-Gaza War - URL: https://www.bbc.com/news/topics/c2vdnvdg6xxt
# 2. War in Ukraine - URL: https://www.bbc.com/news/war-in-ukraine
# 3. World - URL: https://www.bbc.com/news/world
# 4. US & Canada - URL: https://www.bbc.com/news/us-canada
# 5. UK - URL: https://www.bbc.com/news/uk
# 6. In Pictures - URL: https://www.bbc.com/news/in_pictures
# 7. BBC Verify - URL: https://www.bbc.com/news/reality_check
# Enter the number corresponding to the desired topic: 7
# You selected: BBC Verify - URL: https://www.bbc.com/news/reality_check
# Enter the statement to verify: bbc verify
# Matching contexts found:
# Link: https://www.bbc.com/news/world-middle-east-68306915 - Matched: BBC Verify has analysed the latest satellite image from the city in southern Gaza.
# Link: https://www.bbc.com/news/world-middle-east-68159939 - Matched: BBC Verify analysis shows how Houthi tactics have changed, as commercial shipping traffic in the Red Sea halves.
# Link: https://www.bbc.com/news/world-middle-east-68306915 - Matched: BBC Verify has analysed the latest satellite image from the city in southern Gaza.
# Link: https://www.bbc.com/news/world-68298891 - Matched: BBC Verify analyses Ukrainian military footage claiming to show sea drones striking Russian ship in the Black Sea.
# Link: https://www.bbc.com/news/world-middle-east-68277124 - Matched: A BBC Verify investigation found videos showing detainees that legal experts say may breach international law.
# Link: https://www.bbc.com/news/world-middle-east-68159939 - Matched: BBC Verify analysis shows how Houthi tactics have changed, as commercial shipping traffic in the Red Sea halves.
# Link: https://www.bbc.com/news/world-middle-east-68280754 - Matched: BBC Verify looks at Gaza's southernmost city, which is full of people who have fled their homes.
# Link: https://www.bbc.com/news/world-middle-east-68210344 - Matched: BBC Verify looks at whether the air strikes on Yemen are impacting Houthi attacks in the Red Sea.
# Link: https://www.bbc.com/news/world-middle-east-67161936 - Matched: BBC Verify’s Merlyn Thomas examines video of the explosion.

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# Load Dolly model and tokenizer
dolly_model = GPT2LMHeadModel.from_pretrained('EleutherAI/gpt-j-6B')
dolly_tokenizer = GPT2Tokenizer.from_pretrained('EleutherAI/gpt-j-6B')

# Set up GPU if available
device = 'cuda' if torch.cuda.is_available() else 'cpu'
dolly_model.to(device)
# Out:
# You are using a model of type gptj to instantiate a model of type gpt2. This is not supported for all configurations of models and can yield errors.
# /Users/shokbhl/anaconda3/lib/python3.11/site-packages/huggingface_hub/file_download.py:983: UserWarning: Not enough free disk space to download the file. The expected file size is: 24207.82 MB. The target location /Users/shokbhl/.cache/huggingface/hub only has 3283.44 MB free disk space.
#   warnings.warn(
# /Users/shokbhl/anaconda3/lib/python3.11/site-packages/huggingface_hub/file_download.py:983: UserWarning: Not enough free disk space to download the file. The expected file size is: 24207.82 MB. The target location /Users/shokbhl/.cache/huggingface/hub/models--EleutherAI--gpt-j-6B/blobs only has 3283.44 MB free disk space.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/24.2G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 4
#       1 from transformers import GPT2LMHeadModel, GPT2Tokenizer
#       3 # Load Dolly model and tokenizer
# ----> 4 dolly_model = GPT2LMHeadModel.from_pretrained('EleutherAI/gpt-j-6B')
#       5 dolly_tokenizer = GPT2Tokenizer.from_pretrained('EleutherAI/gpt-j-6B')
#       7 # Set up GPU if available
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/modeling_utils.py:3412, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3409     else:
#    3410         # This repo has no safetensors file of any kind, we switch to PyTorch.
#    3411         filename = _add_variant(WEIGHTS_NAME, variant)
# -> 3412         resolved_archive_file = cached_file(
#    3413             pretrained_model_name_or_path, filename, **cached_file_kwargs
#    3414         )
#    3415 if resolved_archive_file is None and filename == _add_variant(WEIGHTS_NAME, variant):
#    3416     # Maybe the checkpoint is sharded, we try to grab the index name in this case.
#    3417     resolved_archive_file = cached_file(
#    3418         pretrained_model_name_or_path,
#    3419         _add_variant(WEIGHTS_INDEX_NAME, variant),
#    3420         **cached_file_kwargs,
#    3421     )
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/utils/hub.py:385, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     382 user_agent = http_user_agent(user_agent)
#     383 try:
#     384     # Load from URL or cache if already cached
# --> 385     resolved_file = hf_hub_download(
#     386         path_or_repo_id,
#     387         filename,
#     388         subfolder=None if len(subfolder) == 0 else subfolder,
#     389         repo_type=repo_type,
#     390         revision=revision,
#     391         cache_dir=cache_dir,
#     392         user_agent=user_agent,
#     393         force_download=force_download,
#     394         proxies=proxies,
#     395         resume_download=resume_download,
#     396         token=token,
#     397         local_files_only=local_files_only,
#     398     )
#     399 except GatedRepoError as e:
#     400     raise EnvironmentError(
#     401         "You are trying to access a gated repo.\nMake sure to request access at "
#     402         f"https://huggingface.co/{path_or_repo_id} and pass a token having permission to this repo either "
#     403         "by logging in with `huggingface-cli login` or by passing `token=<your_token>`."
#     404     ) from e
#
# File ~/anaconda3/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:118, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     115 if check_use_auth_token:
#     116     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 118 return fn(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/huggingface_hub/file_download.py:1457, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, local_dir_use_symlinks, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout, endpoint)
#    1454         if local_dir is not None:
#    1455             _check_disk_space(expected_size, local_dir)
# -> 1457     http_get(
#    1458         url_to_download,
#    1459         temp_file,
#    1460         proxies=proxies,
#    1461         resume_size=resume_size,
#    1462         headers=headers,
#    1463         expected_size=expected_size,
#    1464     )
#    1466 if local_dir is None:
#    1467     logger.debug(f"Storing {url} in cache at {blob_path}")
#
# File ~/anaconda3/lib/python3.11/site-packages/huggingface_hub/file_download.py:527, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, _nb_retries)
#     525 if chunk:  # filter out keep-alive new chunks
#     526     progress.update(len(chunk))
# --> 527     temp_file.write(chunk)
#     528     new_resume_size += len(chunk)
#     529     # Some data has been downloaded from the server so we reset the number of retries.
#
# File ~/anaconda3/lib/python3.11/tempfile.py:483, in _TemporaryFileWrapper.__getattr__.<locals>.func_wrapper(*args, **kwargs)
#     481 @_functools.wraps(func)
#     482 def func_wrapper(*args, **kwargs):
# --> 483     return func(*args, **kwargs)
#
# OSError: [Errno 28] No space left on device

# %%
# Install necessary libraries
# !pip install transformers

# Import required modules
import requests
from bs4 import BeautifulSoup
from transformers import pipeline

# Define the RoBERTa-based question-answering pipeline
qa_pipeline = pipeline("question-answering", model="deepset/roberta-base-squad2", tokenizer="deepset/roberta-base-squad2")

# Continue with the rest of your code...


# Import required modules
import requests
from bs4 import BeautifulSoup
from transformers import pipeline

# Function to get BBC News topics
def get_bbc_news_topics():
    url = 'https://www.bbc.com/news'
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        topics = []

        # Find topics under the 'News' section
        news_section = soup.find('a', {'href': '/news'})
        if news_section:
            topic_list = news_section.find_next('ul')
            if topic_list:
                topics = [(index + 1, topic.text, topic['href']) for index, topic in enumerate(topic_list.find_all('a'))]

        return topics
    else:
        print(f"Error: Unable to fetch topics. Status code: {response.status_code}")
        return []

# Function to scrape data with specified classes
def scrape_with_classes(soup, classes):
    scraped_data = {}
    for class_name in classes:
        elements = soup.find_all(class_=class_name)
        if elements:
            scraped_data[class_name] = [element.get_text(strip=True) for element in elements]

    return scraped_data

# Function to generate responses using the RoBERTa model for question answering
def generate_response_roberta(question, context):
    answer = qa_pipeline(question=question, context=context)
    return answer['answer']

# Scrape BBC news topics
topics = get_bbc_news_topics()

if not topics:
    print("No topics found. Exiting.")
else:
    # Display available topics to the user
    print("Available topics:")
    for topic in topics:
        print(f"{topic[0]}. {topic[1]} - URL: https://www.bbc.com{topic[2]}")

    # Ask the user to choose a topic
    try:
        user_choice = input("Enter the number corresponding to the desired topic: ")
        selected_topic = topics[int(user_choice) - 1]

        print(f"You selected: {selected_topic[1]} - URL: https://www.bbc.com{selected_topic[2]}")
        topic_url = f'https://www.bbc.com{selected_topic[2]}'

        # Make a request for the topic page
        topic_response = requests.get(topic_url)

        if topic_response.status_code == 200:
            soup = BeautifulSoup(topic_response.text, 'html.parser')

            # Classes to check
            classes_to_check = ["gclMev", "dEAAFJ", "czRLo", "jqwZKz", "kTrQIN", "dJMMNx", "crzIlm"]

            # Scrape elements with specified classes
            scraped_data = scrape_with_classes(soup, classes_to_check)

            # Ask the user to enter a question for RoBERTa-based question answering
            user_question = input("Enter a question about the selected topic: ")

            # Use RoBERTa for question answering on the user's question and scraped data
            for class_name, data_list in scraped_data.items():
                for data in data_list:
                    question = f"What is {data} about?"
                    answer = generate_response_roberta(question, user_question)
                    print(f"Question: {question}")
                    print(f"Answer: {answer}")
                    print()

        else:
            print(f"Error: Unable to fetch topic page. Status code: {topic_response.status_code}")

    except (ValueError, IndexError):
        print("Invalid choice. Please enter a valid topic number.")
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.37.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/496M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/79.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]
# Available topics:
# 1. Israel-Gaza War - URL: https://www.bbc.com/news/topics/c2vdnvdg6xxt
# 2. War in Ukraine - URL: https://www.bbc.com/news/war-in-ukraine
# 3. World - URL: https://www.bbc.com/news/world
# 4. US & Canada - URL: https://www.bbc.com/news/us-canada
# 5. UK - URL: https://www.bbc.com/news/uk
# 6. In Pictures - URL: https://www.bbc.com/news/in_pictures
# 7. BBC Verify - URL: https://www.bbc.com/news/reality_check
# Enter the number corresponding to the desired topic: 7
# You selected: BBC Verify - URL: https://www.bbc.com/news/reality_check
# Enter a question about the selected topic: BBC Verify has analysed the latest satellite image from the city in southern Gaza.
# Question: What is The prime minister said five priorities should be used to hold his government to account. about?
# Answer: Gaza.
#
# Question: What is New data suggests that the cost of living has been rising faster than official inflation figures. about?
# Answer: satellite image from the city in southern Gaza
#
# Question: What is The latest figures show the government has not yet met its annual target to build 300,000 new homes. about?
# Answer: Gaza.
#
# Question: What is The government's climate advisers warn the UK risks falling behind on efforts to reach net zero by 2050. about?
# Answer: BBC Verify has analysed the latest satellite image from the city in southern Gaza.
#
# Question: What is Access to education, jobs and public spaces for women have all been curtailed under Taliban rule. about?
# Answer: Gaza.
#
# Question: What is The prime minister gave an update on his policy of stopping small boats crossings. about?
# Answer: Gaza.
#
# Question: What is A BBC investigation has found significant discrepancies in the election results in one region of the country. about?
# Answer: southern Gaza
#
# Question: What is Both parties claim to have cheaper council tax but it's very hard to tell. about?
# Answer: satellite image from the city in southern Gaza.
#
# Question: What is Immigration minister Robert Jenrick wrongly said the UN could help Sudanese refugees come to the UK. about?
# Answer: BBC Verify has analysed the latest satellite image from the city in southern Gaza.
#
# Question: What is Is Rishi Sunak keeping his five key promises? about?
# Answer: Gaza.
#
# Question: What is Benefits falling behind rising cost of living about?
# Answer: Gaza.
#
# Question: What is What's happened to the government's housebuilding target? about?
# Answer: latest satellite image from the city in southern Gaza.
#
# Question: What is Is the UK on track to meet its climate targets? about?
# Answer: BBC Verify has analysed the latest satellite image from the city in southern Gaza.
#
# Question: What is The Taliban's broken promises about?
# Answer: Gaza.
#
# Question: What is Rishi Sunak's claims on small boats fact checked about?
# Answer: satellite image from the city in southern Gaza.
#
# Question: What is The mystery results in Nigeria's disputed election about?
# Answer: BBC Verify has analysed the latest satellite image from the city in southern Gaza.
#
# Question: What is Do Labour or Conservatives have higher council tax? about?
# Answer: Gaza.
#
# Question: What is Can Sudan refugees come to the UK legally? about?
# Answer: BBC Verify has analysed the latest satellite image from the city in southern Gaza.
#
# Question: What is Satellite data reveals at least 144,000 hit since Israeli strikes began, and how south is now bearing the brunt. about?
# Answer: southern Gaza
#
# Question: What is International forces face a huge challenge defending shipping in one of the most important trade routes. about?
# Answer: Gaza.
#
# Question: What is BBC Verify has analysed the latest satellite image from the city in southern Gaza. about?
# Answer: BBC Verify has analysed the latest satellite image from the city in southern Gaza.
#
# Question: What is BBC Verify analysis shows how Houthi tactics have changed, as commercial shipping traffic in the Red Sea halves. about?
# Answer: satellite image from the city in southern Gaza
#
# Question: What is BBC Verify has analysed the latest satellite image from the city in southern Gaza. about?
# Answer: BBC Verify has analysed the latest satellite image from the city in southern Gaza.
#
# Question: What is BBC Verify analyses Ukrainian military footage claiming to show sea drones striking Russian ship in the Black Sea. about?
# Answer: satellite image from the city in southern Gaza
#
# Question: What is A BBC Verify investigation found videos showing detainees that legal experts say may breach international law. about?
# Answer: Gaza
#
# Question: What is BBC Verify analysis shows how Houthi tactics have changed, as commercial shipping traffic in the Red Sea halves. about?
# Answer: satellite image from the city in southern Gaza
#
# Question: What is Russia called footage of bodies in Bucha 'staged' but its evidence for this does not stack up. about?
# Answer: BBC Verify has analysed the latest satellite image from the city in southern Gaza.
#
# Question: What is President Putin has said Western military advisers are actively involved in Ukraine. about?
# Answer: Gaza.
#
# Question: What is President Putin made several claims about Ukraine and Nato in his speech at a military parade in Moscow. about?
# Answer: BBC Verify has analysed the latest satellite image from the city in southern Gaza.
#
# Question: What is China has become a big lender to poorer countries, and there's been criticism of its approach. about?
# Answer: BBC Verify has analysed the latest satellite image from the city in southern Gaza.
#
# Question: What is We've looked at four false Covid vaccine claims that won’t go away. about?
# Answer: BBC Verify has analysed the latest satellite image from the city in southern Gaza
#
# Question: What is BBC Verify looks at Gaza's southernmost city, which is full of people who have fled their homes. about?
# Answer: satellite image
#
# Question: What is BBC Verify looks at whether the air strikes on Yemen are impacting Houthi attacks in the Red Sea. about?
# Answer: satellite image
#
# Question: What is BBC Verify’s Merlyn Thomas examines video of the explosion. about?
# Answer: satellite image
#
# Question: What is Over long distances and with powerful explosive payloads, Ukraine's water drones are proving highly effective. about?
# Answer: BBC Verify has analysed the latest satellite image from the city in southern Gaza
#
# Question: What is BBC security correspondent Frank Gardner looks at three key pieces of video evidence. about?
# Answer: satellite image from the city in southern Gaza
#
# Question: What is Rafah images show huge blast craters close to camps about?
# Answer: Gaza
#
# Question: What is US and UK strikes fail to slow Houthi attacks about?
# Answer: Gaza.
#
# Question: What is At least half of Gaza buildings damaged or destroyed, new analysis shows about?
# Answer: BBC Verify
#
# Question: What is Tracking Houthi attacks in the Red Sea about?
# Answer: satellite image from the city in southern Gaza.
#
# Question: What is Rafah images show huge blast craters close to camps about?
# Answer: Gaza
#
# Question: What is Moment Russian ship struck by Ukrainian drones about?
# Answer: Gaza.
#
# Question: What is Israel to act on soldier misconduct after BBC investigation about?
# Answer: Gaza.
#
# Question: What is US and UK strikes fail to slow Houthi attacks about?
# Answer: Gaza.
#
# Question: What is Bucha satellite image contradicts Russian claims about?
# Answer: BBC Verify has analysed the latest satellite image from the city in southern Gaza
#
# Question: What is Fact-checking Russian claims Nato troops are in Ukraine about?
# Answer: BBC Verify has analysed the latest satellite image from the city in southern Gaza.
#
# Question: What is Putin's Victory Day speech fact-checked about?
# Answer: satellite image
#
# Question: What is Is China luring poorer countries into debt? about?
# Answer: Gaza.
#
# Question: What is No, it won't alter your DNA - vaccine rumours debunked about?
# Answer: BBC Verify has analysed the latest satellite image from the city in southern Gaza.
#
# Question: What is Images from space show how crowded Rafah is about?
# Answer: satellite image from the city in southern Gaza
#
# Question: What is Have Yemen air strikes slowed Houthi attacks? about?
# Answer: Gaza.
#
# Question: What is Searching for clues in video of Gaza hospital explosion about?
# Answer: BBC Verify
#
# Question: What is How Ukraine’s stealthy sea drones strike Russian targets about?
# Answer: Gaza.
#
# Question: What is Is Ukraine’s counter-offensive actually working? about?
# Answer: Gaza.
#
# Question: What is Extremely potent greenhouse gas leaked from a Kazakh well for over six months. about?
# Answer: Gaza.
#
# Question: What is Methane mega-leak exposed in Kazakhstan about?
# Answer: BBC Verify has analysed the latest satellite image from the city in southern Gaza.
